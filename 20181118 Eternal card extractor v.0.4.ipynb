# %% [markdown]
# # Eternal Card Extractor

# %% [markdown]
# ## Section A: Make sure you have the required python 3 modules
# This script was built on Python 3.x and uses pyautogui and opencv 3.4.2. I think the rest of the default Python 3 modules are safe. If the cells below throw errors, you may have problems.

# %%
import sys
assert sys.version[0]=='3'

# %%
import cv2
assert cv2.__version__=='3.4.2'
    # cv2 versions above 3.4.2 do not seem to have xfeatures2d.SIFT methods directly available.
    # When in doubt, force the installation of version 3.4.2.16. I used
    #   pip3 install --user opencv-python==3.4.2.16
    #   pip3 install --user opencv-contrib-python==3.4.2.16
    # Both opencv-python and open-contrib-python seemed to be needed for SIFT to work.

# %%
import pyautogui
import pickle
import gzip

# %% [markdown]
# ## Section B: Grab screenshots of your card collection
# For this section, get Eternal running (maximized is easier) and head to the first screen of your card collection. Afterwards Alt-Tab back to this Jupyter notebook, make sure it is unmaximized and in a position that leaves Eternal visible on the top left corner (so that Python can simulate a click on the Eternal client and bring it to the foreground to take the screenshots), and run the cells below.
#
# (DISCLAIMER: I did not actually run the Section B code from this Jupyter notebook - I ran it from the command line using a script because I do not have Jupyter on the machine where I have Eternal installed. The script I did use is also available on the github repo. Be careful in any case: the script for reasons unknown generates two screenshots of the first page of the collection, which is ok but meeses up the number of cards owned of those cards. If you end up with duplicate screenshots, clean up!)

# %%
import pyautogui

# %%
max_screenshots=150
eternal_x,eternal_y=10,10
    # Position to click on in order to bring Eternal to the foreground
next_x,next_y=0.855*pyautogui.size()[0],0.525*pyautogui.size()[1]
    # Position to click to move to the next collection page 
    # next_x,next_y=1170,400 # Works well for a screen resolution of 1366 x 768
screenshots_folder='./Screenshots/'

# %%
pyautogui.click(eternal_x,eternal_y)

cnt=0
old_screenshot=None
done=False
while (not done) and (cnt<max_screenshots):
    cnt=cnt+1
    new_screenshot=pyautogui.screenshot()
    if new_screenshot!=old_screenshot:
        new_screenshot.save(screenshots_folder+'ss{:03d}.png'.format(cnt))
        old_screenshot=new_screenshot
        pyautogui.click(next_x,next_y)
    else:
        done=True

# %% [markdown]
# ## Section C: Identify card collection

# %% [markdown]
# ### Section C.1: Load card artwork features

# %% [markdown]
# The library is based on the one in Eternal Warcry - thanks for allowing me to use it for this project!
#
# The pickle module is very nice but can lead to incompatibilities. If it cannot unpickle the library, let me know so that I can think of an alternative way of serializing it.

# %%
import pickle
import gzip

# %%
library_local='./card_library.gz'
    # A pickled version of the library with the artwork descriptors already calculated
    # that I prepared so that you don't have to.

# %%
with gzip.open(library_local,'rb') as library_file:
    library=pickle.load(library_file)

# %% [markdown]
# ### Section C.2: Process screenshots

# %%
import pyautogui
import cv2
import os

# %%
img_w,img_h=80,80
    # Size in pixels of the box used to extract features from.
    # Limited by either the resolution of your screen or that of the card artwork.
    # 80x80 was used to construct the card library.
nfeatures=50
    # Number of features to extract from each box. 50 works well with 80x80 boxes.

    # This area has some upside potential by the way - identifying less features based
    # on lower resolution boxes would speed up the process and produce a smaller
    # card library file. To be explored.
sift=cv2.xfeatures2d.SIFT_create(nfeatures=nfeatures)

# %% [markdown]
# The functions below seem fairly common for this specific purpose. My understanding of them is incomplete, but the first one seems to return the good matching features between two descriptor sets (and will be used once between the target and each of the possible option images), and the second one seems to compute how may of the total matching features that were considered good came from each classification option (and will be used once, after all of the options have been evaluated).
#
# The option that generated the highest number of good matching features is the most likely one.

# %%
def knn_match(des1, des2, nn_ratio=0.7):
    index_params = dict(algorithm = 0, trees = 5)
    search_params = dict(checks = 50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(des1, des2, k=2)
    good = []
    for m, n in matches:
        if m.distance < nn_ratio * n.distance:
            good.append(m)
    return good

def knn_clasif(good_matches):
    logprobs=[]
    best_template, highest_logprob = None, 0.0
    sum_good_matches = sum([len(gm) for gm in good_matches])
    for i, gm in enumerate(good_matches):
        logprob = len(gm)/sum_good_matches
        logprobs.append(logprob)
        if logprob > highest_logprob:
            highest_logprob = logprob
            best_template = i
    return best_template,logprobs

# %% [markdown]
# The parameters below define the places in the screenshots where we will extract image boxes and number owned diamonds from. Plenty of options would be available; I went for estimating:
# - The distance between cards (sep_x,sep_y), which when aplied to the position of the top left corner of the first image box (crd_x,crd_y) generates the boxes that will be used to extract owned card features (pos_lst)
# - The distance between the cards (the same sep_x,sep_y) and the horizontal distance between the ownership diamonds (sep_cnt), which when applied to the position of the center of the second diamond (the first one is a given - you always have at least one card of those present in the screenshots) of the top left card (cnt_x,cnt_y) generates the points to check if an ownership diamond is present (cnt_lst). This test is done against a cutoff of 100, but the actual values measured on the screenshots were 330 on yes-diamond and 15 on no-diamond
#
# There is another notebook in the repo to help finetune these parameters.

# %%
screenshots_folder='./Screenshots/'
collection_file='./my_collection.txt'

sep_x,sep_y=int(0.122*pyautogui.size()[0]),int(0.383*pyautogui.size()[1])
    # Represents the distances between equivalent positions of cards on the screenshot,
    # i.e., 'top left to top left' or 'center to center', or whatever
    # sep_x,sep_y=166,295 # Works well for a screen resolution of 1366 x 768   
crd_x,crd_y=int(0.172*pyautogui.size()[0]),int(0.211*pyautogui.size()[1])
    # Represents the top left corner of the feature extraction box of the first card
    # crd_x,crd_y=234,162 # Works well for a screen resolution of 1366 x 768
pos_lst=[ (crd_x+n_x*sep_x,crd_y+n_y*sep_y,img_w,img_h)
          for n_y in range(2) for n_x in range(6)]
    # Represent the list of feature extraction boxes of the 12 cards

sep_cnt=int(0.013*pyautogui.size()[0])
    # Represents the horizontal distance between equivalent positions of diamods on the screenshot
    # i.e., 'top left to top left' or 'center to center', or whatever
    # sep_cnt=17 # Works well for a screen resolution of 1366 x 768
cnt_x,cnt_y=int(0.192*pyautogui.size()[0]),int(0.146*pyautogui.size()[1])
    # Represents the center of the second ownership diamond of the first card
    #cnt_x,cnt_y=262,112 # Works well for a screen resolution of 1366 x 768
cnt_lst=[ [(cnt_x+n_x*sep_x+n_cnt*sep_cnt,cnt_y+n_y*sep_y) for n_cnt in range(3)]
          for n_y in range(2) for n_x in range(6)]
    # Represents the center of the second, third, and fourth diamonds of the 12 cards

owned_threshold=100
    # Threshold to determine whether at the point there is a yes-diamond or no-diamond.
    # The actual numbers are 330 for yes-diamond and 15 for no-diamond

# %% [markdown]
# The script extracts each card in each screenshot of the collection, compares its features with those of all the cards in the library, and finds the best match.
#
# It can be made much faster by identifying additional features from the cards, such as power requirements profile, cost, or attack; these can then be used to narrow the search for the target card, which would also allow to reduce the size of the feature extraction boxes and the number of features being extracted from each box.
#
# I also tried text extraction, but tesseract did not work well on the card names, at least not on my low resolution screenshots. That however does not mean it cannot be used to speed up the identification process, as long as the extracted gibberish is consistent.
#
# To be explored.

# %%
# %%time

list_cards=list(library)
for card in library:
    library[card]['owned']=0
errors=[]
tot=len(os.listdir(screenshots_folder))
cnt=0
for ss_file in sorted(os.listdir(screenshots_folder)):
    cnt=cnt+1
    print('[{:3d}/{:3d}] Processing file {}...'.format(cnt,tot,ss_file))
    if ss_file[-3:]=='png':
        screenshot=cv2.imread(screenshots_folder+ss_file)
        for i in range(12):
            l,t,w,h=pos_lst[i]
            target=cv2.resize(screenshot[t:t+h,l:l+w],(img_w,img_h))
            try:
                _,descriptors=sift.detectAndCompute(target,None)
                list_good_matches=[]
                for card in library:
                    list_good_matches.append(knn_match(library[card]['descriptors'],descriptors))
                best_match,probs=knn_clasif(list_good_matches)
                num_owned=1+sum([ screenshot[c[1],c[0],:].sum()>owned_threshold for c in cnt_lst[i]])
                print(12*' '+'- {} '.format(num_owned)+list_cards[best_match])
                library[list_cards[best_match]]['owned']=min(4,library[list_cards[best_match]]['owned']+num_owned)
            except:
                errors.append('[ERROR] Problem identifying card {:2d} in screenshot {}!'.format(i+1,ss_file))
                print(errors[-1])
                pass
# Out:
# [  1/ 99] Processing file .ipynb_checkpoints...
# [  2/ 99] Processing file grab_ss.py...
# [  3/ 99] Processing file ss001.png...
#             - 4 Seek Power
#             - 1 Fire Sigil
#             - 4 Granite Monument
#             - 1 Granite Monument
#             - 4 Granite Waystone
#             - 3 Shugo Standard
#             - 3 Helpful Doorbot
#             - 1 Trail Stories
#             - 4 Bore
#             - 3 Drifter
#             - 4 Firemane Cub
#             - 4 Forge Wolf
# [  4/ 99] Processing file ss002.png...
#             - 4 Grenadin Drone
#             - 4 Heavy Axe
#             - 4 Hidden Shiv
#             - 1 Hidden Shiv
#             - 3 Iceberg Frontrunner
#             - 1 Kaleb's Intervention
#             - 4 Light 'em Up
#             - 2 Mindfire
#             - 4 On the Hunt
#             - 4 Oni Dragonsmith
#             - 4 Oni Ronin
#             - 4 Pummel
# [  5/ 99] Processing file ss003.png...
#             - 4 Pyroknight
#             - 4 Rambot
#             - 4 Ruin
#             - 1 Ruin
#             - 4 Ruthless Stranger
#             - 3 Scrap Hound
#             - 4 Signal Flare
#             - 4 Temper
#             - 4 Ticking Grenadin
#             - 4 Torch
#             - 4 Warhelm
#             - 4 Young Gun
# [  6/ 99] Processing file ss004.png...
#             - 1 Ankle Cutter
#             - 4 Bladekin Apprentice
#             - 4 Blazing Renegade
#             - 4 Blinkwolf
#             - 4 Cauldron Cookbook
#             - 1 Charchain Flail
#             - 1 Consuming Flames
#             - 3 Disassembler
#             - 4 Flame Blast
#             - 1 Flamefang Charmer
#             - 1 Flamefang Charmer
#             - 1 Grenarender
# [  7/ 99] Processing file ss005.png...
#             - 4 Hotblood Barbarian
#             - 4 Into the Furnace
#             - 4 Kaleb's Favor
#             - 1 Kaleb's Favor
#             - 2 Oni Cavediver
#             - 4 Ornate Katana
#             - 4 Piercing Shot
#             - 4 Pyre Adept
#             - 1 Pyre Adept
#             - 4 Rakano Outlaw
#             - 4 Rampage
#             - 4 Ruination Sledge
# [  8/ 99] Processing file ss006.png...
#             - 1 Ruination Sledge
#             - 4 Smith's Hammer
#             - 1 Song of War
#             - 4 Spark Hatcher
#             - 2 Trick Shot
#             - 3 Unpredictable Outlaw
#             - 2 Yeti Sage
#             - 4 Assembly Line
#             - 4 Backpacker's Machete
#             - 4 Cinder Yeti
#             - 4 Fevered Scout
#             - 4 First-Shot Rioter
# [  9/ 99] Processing file ss007.png...
#             - 2 Frontier Bard
#             - 4 Granite Acolyte
#             - 1 Granite Acolyte
#             - 4 Granite Ring
#             - 1 Granite Ring
#             - 4 Grenade
#             - 1 Grenade
#             - 4 Hipshot
#             - 1 Honor the Ancestors
#             - 3 Hoof Slash
#             - 1 Ixtun Merchant
#             - 4 Jawbone Hatchet
# [ 10/ 99] Processing file ss008.png...
#             - 4 Kindle
#             - 1 Manufacture
#             - 3 Oni Eulogist
#             - 4 Oni Quartermaster
#             - 4 Praxis Outlaw
#             - 4 Rakano Flagbearer
#             - 4 Rally
#             - 4 Rebel Sharpshooter
#             - 3 Ruincrawler Yeti
#             - 1 Rusty Grenamotive
#             - 2 Scrap Heap
#             - 2 Shogun's Scepter
# [ 11/ 99] Processing file ss009.png...
#             - 4 Sparkbot
#             - 4 Stonescar Excavator
#             - 4 Stoneshaker
#             - 4 Temple Raider
#             - 1 Toppletower
#             - 3 Tumblebang
#             - 4 Twinbarrel
#             - 2 Twinbarrel
#             - 4 Warpainter
#             - 1 Won't Be Pretty
#             - 2 Ancient Defenses
#             - 4 Arms Enthusiast
# [ 12/ 99] Processing file ss010.png...
#             - 4 Audacious Bandit
#             - 3 Audacious Bandit
#             - 4 Barbarian Camp
#             - 4 Burn Out
#             - 4 Centaur Outrider
#             - 2 Cloud of Ash
#             - 1 Cloud of Ash
#             - 4 Crimson Firemaw
#             - 1 Criva, the Crimson Scythe
#             - 1 Furnace Mage
#             - 4 Grenadin Cannoneer
#             - 4 Groundbreaker
# [ 13/ 99] Processing file ss011.png...
#             - 4 Guerrilla Fighter
#             - 1 Iceberg Scattershot
#             - 3 Library Phoenix
#             - 4 Magma Javelin
#             - 2 Magma Javelin
#             - 4 Morningstar
#             - 4 Outlands Brute
#             - 4 Outlands Sniper
#             - 4 Overheat
#             - 4 Rebel Illuminator
#             - 4 Recogulator
#             - 4 Reforge
# [ 14/ 99] Processing file ss012.png...
#             - 3 Scalechannel Sorcerer
#             - 2 Steelfang Chakram
#             - 1 Stonescar Sawed-Off
#             - 4 Swift Stranger
#             - 1 Swift Stranger
#             - 4 Thunderhoof Warrior
#             - 3 Wandering Forge
#             - 4 Welding Torch
#             - 4 Bait
#             - 2 Calderan Gunsmith
#             - 3 Centaur Raidleader
#             - 4 Dustblind
# [ 15/ 99] Processing file ss013.png...
#             - 4 Dusthoof Brawler
#             - 4 Fiery Fissure
#             - 4 Flash Fire
#             - 4 Gun Down
#             - 1 Gun Down
#             - 4 Obliterate
#             - 4 Oni Striker
#             - 1 Parapet Sentry
#             - 4 Pit Fighter
#             - 4 Pouncing Drake
#             - 3 Powderkeg Rider
#             - 2 Robobuddy
# [ 16/ 99] Processing file ss014.png...
#             - 3 Staff of the Arch-Magister
#             - 4 Stonepowder Heretic
#             - 1 Stonepowder Heretic
#             - 1 Wildfire Censari
#             - 2 Barkeep's Friend
#             - 4 Cannonbearer
#             - 4 Crowd Favorite
#             - 4 Frontline Cyclops
#             - 3 General Izalio
#             - 4 Hellfire Rifle
#             - 1 Oni Gunwright
#             - 3 Pyre Elemental
# [ 17/ 99] Processing file ss015.png...
#             - 3 Stonescar Maul
#             - 3 Tempered Sentinel
#             - 2 Worldpyre Phoenix
#             - 4 Burning Glaive
#             - 1 Claw of the First Dragon
#             - 4 Core Scavenger
#             - 2 Final Shot
#             - 1 Improvised Rubbler
#             - 2 Steelbound Dragon
#             - 1 Heroic Bravo
#             - 2 Kaleb, Uncrowned Prince
#             - 1 Lavablood Goliath
# [ 18/ 99] Processing file ss016.png...
#             - 1 Sindok, Rage Incarnate
#             - 1 Time Sigil
#             - 4 Amber Monument
#             - 3 Amber Waystone
#             - 3 Temple Standard
#             - 4 Sand Warrior
#             - 3 Amaran Shoveler
#             - 3 Ancient Bauble
#             - 4 Cult Aspirant
#             - 2 Entrancer
#             - 4 Envelop
#             - 4 Excavate
# [ 19/ 99] Processing file ss017.png...
#             - 4 Excavation Assistant
#             - 1 Excavation Assistant
#             - 2 Gloaming Wisp
#             - 4 Humbug
#             - 2 Humbug
#             - 4 Infinite Hourglass
#             - 1 Infinite Hourglass
#             - 4 Initiate of the Sands
#             - 1 Initiate of the Sands
#             - 1 Jibbering Jackal
#             - 3 Journey Guide
#             - 4 Lucky Prospector
# [ 20/ 99] Processing file ss018.png...
#             - 4 Meditation
#             - 4 Ornamental Daggers
#             - 4 Predator's Instinct
#             - 4 Sanctuary Priest
#             - 2 Silence
#             - 4 Slow
#             - 1 Slow
#             - 1 Staff of Speed
#             - 1 Training Ground
#             - 4 Water of Life
#             - 4 Accelerate
#             - 4 Bold Adventurer
# [ 21/ 99] Processing file ss019.png...
#             - 2 Copper Conduit
#             - 1 Cirso's Cleaver
#             - 1 Cryptic Etchings
#             - 1 Disjunction
#             - 1 Ephemeral Wisp
#             - 3 Evelina, Valley Searcher
#             - 3 Find the Way
#             - 2 Forgotten Find
#             - 4 Friendly Wisp
#             - 2 Illumination Wisp
#             - 1 Last Rites
#             - 4 Learned Herbalist
# [ 22/ 99] Processing file ss020.png...
#             - 4 Living Example
#             - 1 Living Offering
#             - 3 Nocturnal Creeper
#             - 4 Oasis Seeker
#             - 4 Power Stone
#             - 4 Refresh
#             - 1 Refresh
#             - 4 Sand Viper
#             - 4 Sandglass Parma
#             - 4 Sandstorm
#             - 1 Sandstorm
#             - 4 Sauropod Wrangler
# [ 23/ 99] Processing file ss021.png...
#             - 4 Sauropod Wrangler
#             - 4 Synchronized Strike
#             - 4 Talir's Favored
#             - 1 Talir's Favored
#             - 4 Teleport
#             - 4 Temple Scribe
#             - 4 Trail Maker
#             - 4 Trail Runner
#             - 1 Voice of the Speaker
#             - 4 Xenan Initiation
#             - 4 Ageless Mentor
#             - 4 Amber Acolyte
# [ 24/ 99] Processing file ss022.png...
#             - 4 Amber Ring
#             - 4 Avirax Familiar
#             - 3 Baying Serasaur
#             - 2 Clockroach
#             - 2 Dawnwalker
#             - 4 Decay
#             - 1 Decay
#             - 2 Deft Strike
#             - 4 Determined Stranger
#             - 4 Dilphex Stalker
#             - 4 Disciplined Amanera
#             - 4 Dispel
# [ 25/ 99] Processing file ss023.png...
#             - 1 Dispel
#             - 2 Gear Master
#             - 2 Gravetender
#             - 2 Initiation Bell
#             - 2 Lastlight Infusion
#             - 1 Lastlight Infusion
#             - 2 Lunar Magus
#             - 2 Moondial
#             - 3 Oasis Sanctuary
#             - 2 Premonition Wisp
#             - 2 Reliquary Raider
#             - 4 Scorpion Wasp
# [ 26/ 99] Processing file ss024.png...
#             - 3 Seasoned Spelunker
#             - 1 Secret Pages
#             - 2 Serene Excavator
#             - 4 Shepherd's Horn
#             - 4 Sirocco Elementalist
#             - 4 Spiteful Lumen
#             - 4 Unlock Potential
#             - 2 Watchful Amanera
#             - 2 Ageless Sentinel
#             - 4 Ancient Lore
#             - 4 Archive Curator
#             - 3 Beckoning Lumen
# [ 27/ 99] Processing file ss025.png...
#             - 1 Bolster
#             - 4 Camp Physician
#             - 4 Devoted Theurge
#             - 1 Fantastic Revelation
#             - 2 Fierce Mosaraptor
#             - 2 Gathering Lights
#             - 4 Healer's Cloak
#             - 4 Hissing Spiketail
#             - 4 Horned Vorlunk
#             - 1 Horned Vorlunk
#             - 1 Insatiable Serasaur
#             - 1 Insistent Automaton
# [ 28/ 99] Processing file ss026.png...
#             - 4 Lost in the Mist
#             - 1 Lumen Attendant
#             - 3 Marisen's Disciple
#             - 1 Sandspitter
#             - 2 Sandspout Mirage
#             - 2 Sandstorm Titan
#             - 4 Snapping Brushstalker
#             - 2 Snapping Brushstalker
#             - 1 Steward of Prophecy
#             - 1 Stinging Wind
#             - 4 Striped Araktodon
#             - 1 Striped Araktodon
# [ 29/ 99] Processing file ss027.png...
#             - 4 Timekeeper
#             - 4 Towertop Patrol
#             - 1 Vault of the Praxis
#             - 4 Venom Rider
#             - 4 Viper's Bite
#             - 3 Wurmstone
#             - 4 Xenan Guardian
#             - 1 Xenan Obelisk
#             - 4 Amaran Archaeologist
#             - 4 Awakened Sentinel
#             - 1 Awakened Sentinel
#             - 4 Battle-Tested Stranger
# [ 30/ 99] Processing file ss028.png...
#             - 1 First Watch
#             - 4 Fishing Dinoch
#             - 2 Frenzied Omnivore
#             - 4 Lumen Defender
#             - 2 Mistress of Light
#             - 2 Pensive Lumen
#             - 4 Praxis Displacer
#             - 2 Sandbinder Sentinel
#             - 2 Striking Snake Formation
#             - 4 Time Weaver
#             - 4 Towering Terrazon
#             - 4 Twinbrood Sauropod
# [ 31/ 99] Processing file ss029.png...
#             - 3 Vital Arcana
#             - 4 Waystone Infuser
#             - 1 Waystone Infuser
#             - 1 Wurmic Chanter
#             - 4 Bury the Past
#             - 4 Humbug Swarm
#             - 4 Lumen Shepherd
#             - 4 Pack Hunt
#             - 4 Passage of Eons
#             - 4 Plated Goliath
#             - 1 Plated Goliath
#             - 1 Sentinel's Might
# [ 32/ 99] Processing file ss030.png...
#             - 4 Timeworn Sentinel
#             - 1 Tomb Protector
#             - 4 Voyaging Lumen
#             - 4 Dormant Sentinel
#             - 1 Elysian Pathfinder
#             - 1 Elysian Pathfinder
#             - 3 Hall of Lost Kings
#             - 4 Hibernating Behemoth
#             - 4 Pillar of Amar
#             - 1 Pillar of Amar
#             - 4 Predatory Carnosaur
#             - 2 Reality Shift
# [ 33/ 99] Processing file ss031.png...
#             - 1 Reality Shift
#             - 1 Serasaur Bull
#             - 4 Subterranean Sentry
#             - 1 Talir, Unbound
#             - 4 Tesya, Omen Shaper
#             - 4 Belching Behemoth
#             - 1 Belching Behemoth
#             - 2 Dinosaur Stampede
#             - 1 Intriguing Ancient
#             - 3 Talir, Who Sees Beyond
#             - 4 Scourstone Sentinel
#             - 3 Foraging Sauropod
# [ 34/ 99] Processing file ss032.png...
#             - 1 Justice Sigil
#             - 1 Crownwatch Standard
#             - 2 Emerald Monument
#             - 4 Emerald Waystone
#             - 4 Crownwatch Squire
#             - 4 Detain
#             - 4 District Infantry
#             - 1 District Infantry
#             - 4 Elder's Feather
#             - 4 Finest Hour
#             - 1 Ironfist Faithful
#             - 4 Lingering Influence
# [ 35/ 99] Processing file ss033.png...
#             - 4 Minotaur Oathkeeper
#             - 4 Peacekeeper's Helm
#             - 1 Rolant's Intervention
#             - 4 Sharpened Reflex
#             - 4 Spire Spellsword
#             - 4 Steadfast Deputy
#             - 4 Steady Marshal
#             - 4 Tinker Apprentice
#             - 4 Valkyrie Aspirant
#             - 4 Arcane Defense
#             - 4 Argenport Soldier
#             - 4 Copperhall Herald
# [ 36/ 99] Processing file ss034.png...
#             - 2 Copperhall Herald
#             - 4 Copperhall Porter
#             - 2 Crackshot Fugitive
#             - 4 Crownwatch Longsword
#             - 4 Crownwatch Paladin
#             - 3 Eager Owlet
#             - 1 Eager Owlet
#             - 4 Icaria, Valkyrie Captain
#             - 4 Inspire
#             - 3 Master-at-Arms
#             - 4 Minotaur Grunt
#             - 4 Minotaur Grunt
# [ 37/ 99] Processing file ss035.png...
#             - 2 Paladin Oathbook
#             - 4 Protect
#             - 1 Rampart Protector
#             - 4 Rebuke
#             - 4 Reinforce
#             - 2 Reinvigorate
#             - 4 Rolant's Favor
#             - 1 Rolant's Favor
#             - 4 Soaring Guard
#             - 4 Sparring Partner
#             - 4 Stalwart Silverwing
#             - 4 Strength of Many
# [ 38/ 99] Processing file ss036.png...
#             - 4 Talon of Nostrix
#             - 4 Tinker
#             - 1 Tinker
#             - 4 Tinker Overseer
#             - 4 Tranquil Scholar
#             - 4 Vanquish
#             - 1 Wanted Poster
#             - 2 Auric Herdward
#             - 4 Auric Sentry
#             - 4 Brightmace Paladin
#             - 4 Copperhall Bailiff
#             - 1 Copperhall Bracers
# [ 39/ 99] Processing file ss037.png...
#             - 4 Copperhall Cudgel
#             - 4 Copperhall Marshal
#             - 4 Copperhall Shieldman
#             - 4 Emerald Acolyte
#             - 4 Emerald Ring
#             - 4 Fencing Master
#             - 1 Fencing Master
#             - 4 Gilded Glaive
#             - 3 Grit
#             - 2 Guard Dog
#             - 4 Herald of the Parliament
#             - 4 Hero of the People
# [ 40/ 99] Processing file ss038.png...
#             - 4 Highbranch Sentry
#             - 2 Hooru Envoy
#             - 3 Kosul Battlemage
#             - 2 Longhorn Treasurer
#             - 4 Loyal Watchwing
#             - 2 Mark of Shame
#             - 3 Miner's Canary
#             - 1 Order of the Spire
#             - 1 Privilege of Rank
#             - 1 Privilege of Rank
#             - 2 Reinforced Baton
#             - 2 Rolant's Memorial
# [ 41/ 99] Processing file ss039.png...
#             - 3 Saddle Up
#             - 2 Signal Flag
#             - 4 Silverwing Familiar
#             - 2 Silverwing Smith
#             - 2 Spire Chaplain
#             - 4 Spirit Guide
#             - 3 Tandem Watchwing
#             - 4 Tireless Stranger
#             - 1 Tireless Stranger
#             - 4 Treasury Guard
#             - 2 Unseen Commando
#             - 3 Valkyrie Cadet
# [ 42/ 99] Processing file ss040.png...
#             - 4 Valkyrie Enforcer
#             - 3 Valorous Stranger
#             - 1 Warrant Officer
#             - 1 Warrant Officer
#             - 4 Armorsmith
#             - 4 Auric Runehammer
#             - 4 Bronze Cuirass
#             - 1 Citywide Ban
#             - 2 Copperhall Blessing
#             - 4 Copperhall Paladin
#             - 4 Copperhall Recruit
#             - 2 Copperhall Recruit
# [ 43/ 99] Processing file ss041.png...
#             - 4 Crownwatch Cavalry
#             - 4 Crownwatch Press-Gang
#             - 1 Frontier Confessor
#             - 4 Graceful Calligrapher
#             - 1 Ground Crew
#             - 4 Hammer of Might
#             - 4 Inquisitor's Blade
#             - 2 Ironclad Oath
#             - 1 Ironclad Oath
#             - 1 Lawman's Sidearm
#             - 4 Mantle of Justice
#             - 4 Peacekeeper's Prod
# [ 44/ 99] Processing file ss042.png...
#             - 4 Rabblerouser
#             - 1 Rakano Sheriff
#             - 4 Shard of the Spire
#             - 2 Sheriff Marley
#             - 1 Sheriff's Hat
#             - 4 Shielded Shortbarrel
#             - 4 Silverwing Avenger
#             - 2 Sky Crew
#             - 4 Spiked Buckler
#             - 1 Spiritblade Stalker
#             - 4 Stalwart Shield
#             - 1 Valkyrie Bodyguard
# [ 45/ 99] Processing file ss043.png...
#             - 4 Valkyrie Militant
#             - 1 Valkyrie Militant
#             - 4 Valkyrie Spireguard
#             - 4 Victor's Cry
#             - 2 Victor's Cry
#             - 1 Amilli, Cloudmarshal
#             - 4 Combrei Magister
#             - 4 Crownwatch Recruiter
#             - 2 Downfall
#             - 1 Harsh Rule
#             - 4 Hone
#             - 4 Hooru Fledgling
# [ 46/ 99] Processing file ss044.png...
#             - 1 Hooru Fledgling
#             - 4 Minotaur Duelist
#             - 4 Mithril Mace
#             - 1 Rampart Arbalest
#             - 4 Scepter of Nobility
#             - 3 Silverwing Commander
#             - 3 Throne Warden
#             - 4 Twinstrike Master
#             - 4 Aerialist's Khopesh
#             - 1 Aerialist's Khopesh
#             - 2 Augmented Form
#             - 4 Ceremonial Mask
# [ 47/ 99] Processing file ss045.png...
#             - 4 Civic Peacekeeper
#             - 4 Fourth-Tree Elder
#             - 1 Heirloom Blade
#             - 4 Horngrinder
#             - 1 Ironfist Archon
#             - 4 Prosecutor-at-Arms
#             - 4 Roosting Owl
#             - 2 Silverwing Purgeleader
#             - 2 Tower Shield
#             - 2 Town Watchman
#             - 2 Valkyrie Arcanist
#             - 1 Valkyrie Wings
# [ 48/ 99] Processing file ss046.png...
#             - 4 Watchwing Conscript
#             - 1 Aerial Attendant
#             - 1 Crown of Authority
#             - 3 Emerald Spear
#             - 4 Flight Lieutenant
#             - 1 Leave a Witness
#             - 2 Rolant's Honor Guard
#             - 2 Silverwing Augmentor
#             - 1 Rolant, the Iron Fist
#             - 1 Sword of the Sky King
#             - 4 Valkyrie Linebreaker
#             - 1 Silverwing Rallier
# [ 49/ 99] Processing file ss047.png...
#             - 1 Primal Sigil
#             - 2 Clan Standard
#             - 4 Cobalt Monument
#             - 3 Cobalt Waystone
#             - 4 Blind Storyteller
#             - 4 Cliffside Porter
#             - 4 Cloudsnake Hatchling
#             - 2 Eilyn's Intervention
#             - 3 Farplace Finder
#             - 4 Gift of Battle
#             - 4 Hearty Stranger
#             - 4 Jump Kick
# [ 50/ 99] Processing file ss048.png...
#             - 4 Permafrost
#             - 1 Powderglider
#             - 2 Savage Denial
#             - 2 Savage Skybrood
#             - 2 Shiver
#             - 1 Shiver
#             - 4 Sinister Opportunist
#             - 1 Snowcrust Yeti
#             - 2 Snowrager
#             - 2 Substitute
#             - 4 Unstable Form
#             - 4 Weather the Storm
# [ 51/ 99] Processing file ss049.png...
#             - 1 Weather the Storm
#             - 4 Yeti Spy
#             - 4 Backlash
#             - 4 Borderlands Waykeeper
#             - 2 Campfire Watchman
#             - 2 Changeestik
#             - 4 Cloudsnake Breeder
#             - 1 Cloudsnake Saddle
#             - 4 Darkbolt
#             - 2 Darkveil Agent
#             - 4 Dragonbreath
#             - 2 Dusk Raider
# [ 52/ 99] Processing file ss050.png...
#             - 4 East-Wind Herald
#             - 4 Eilyn's Favor
#             - 1 Eilyn's Favor
#             - 2 Entangling Vines
#             - 4 Fearless Yeti
#             - 2 Gruanform
#             - 4 Herald's Song
#             - 3 Horizon Seeker
#             - 3 Huddle Together
#             - 1 Iceberg Mason
#             - 4 Levitate
#             - 4 Lightning Storm
# [ 53/ 99] Processing file ss051.png...
#             - 4 Lightning Strike
#             - 4 Maelstrom Bell
#             - 1 Mating Call
#             - 4 Scaly Gruan
#             - 1 Scaly Gruan
#             - 4 Second Sight
#             - 4 Snowfort Trumpeter
#             - 4 Static Bolt
#             - 2 Strategize
#             - 4 Talon Dive
#             - 1 Talon Dive
#             - 1 Tend the Flock
# [ 54/ 99] Processing file ss052.png...
#             - 4 Trailblaze
#             - 2 Twilight Hermit
#             - 2 Unseal
#             - 4 Violent Gust
#             - 1 Whispering Wind
#             - 4 Wild Cloudsnake
#             - 4 Winter's Grasp
#             - 4 Yeti Snowchucker
#             - 4 Yeti Snowslinger
#             - 4 Yeti Windflyer
#             - 1 Acquisitive Crow
#             - 3 Advance Scout
# [ 55/ 99] Processing file ss053.png...
#             - 4 Cloudsnake Harrier
#             - 4 Cobalt Acolyte
#             - 4 Cobalt Ring
#             - 4 Crafty Yeti
#             - 1 Crafty Yeti
#             - 1 Daring Pioneer
#             - 2 Electropy
#             - 1 Eye of Winter
#             - 4 Flash Freeze
#             - 4 Foothills Alpha
#             - 1 Horde Plunderer
#             - 4 Ice Sprite
# [ 56/ 99] Processing file ss054.png...
#             - 4 Icebow
#             - 2 Icebreaker
#             - 2 Jennev Merchant
#             - 3 Lethrai Darkstalker
#             - 1 Mind Link
#             - 4 Mirror Image
#             - 4 Polymorph
#             - 1 Rabid Yeti
#             - 1 Rabid Yeti
#             - 4 Skyrider Vanguard
#             - 1 Skyrider Vanguard
#             - 4 Skysnapper
# [ 57/ 99] Processing file ss055.png...
#             - 1 Snowfort
#             - 4 South-Wind Herald
#             - 4 Stormcrasher
#             - 1 Stormcrasher
#             - 1 Sunken Tower
#             - 1 Temple Shihan
#             - 4 Thunderbird
#             - 1 Tundra Explorer
#             - 2 Voracious Fosora
#             - 4 Wild Rider
#             - 4 Wisdom of the Elders
#             - 1 Wump, Party Starter
# [ 58/ 99] Processing file ss056.png...
#             - 2 Yeti Furflinger
#             - 1 Clutchmate
#             - 4 Cutbrush Cartographer
#             - 1 Freewing Glider
#             - 4 Galeprowler
#             - 1 Icespear Chucker
#             - 4 Jarrall's Frostkin
#             - 1 Jarrall's Frostkin
#             - 4 Jotun Cyclops
#             - 4 Nocturnal Kyrex
#             - 1 Rain of Frogs
#             - 1 Resurface
# [ 59/ 99] Processing file ss057.png...
#             - 4 Ridgeline Watcher
#             - 3 Scavenging Spikeback
#             - 4 Serpent Mount
#             - 1 Serpent Mount
#             - 4 Serpent Trainer
#             - 4 Serpent Trainer
#             - 4 Skyward Seer
#             - 3 Slushdumper
#             - 3 Soaring Stranger
#             - 1 Spiritward Shaman
#             - 4 Stormcaller
#             - 4 Torgov, Icecap Trader
# [ 60/ 99] Processing file ss058.png...
#             - 4 Tyrannize
#             - 4 Windshaper
#             - 4 Yeti Troublemaker
#             - 4 Yetipult
#             - 4 Aerial Ace
#             - 4 Cliffside Caretaker
#             - 3 Crystallize
#             - 1 First-Frost Shaman
#             - 2 Gleaming Shield
#             - 4 Jotun Hurler
#             - 4 Jotun Punter
#             - 1 Jotun Punter
# [ 61/ 99] Processing file ss059.png...
#             - 4 Jotun Warrior
#             - 1 Magus of the Mist
#             - 4 Primal Incarnation
#             - 4 Psionic Savant
#             - 4 Skycrag Wyvarch
#             - 4 Skywalk Instructor
#             - 1 Staff of Stories
#             - 2 Stampede Driver
#             - 4 Swindle
#             - 1 Swindle
#             - 1 West-Wind Herald
#             - 4 Boltcrafter Shaman
# [ 62/ 99] Processing file ss060.png...
#             - 1 Celestial Omen
#             - 4 Cirso's Meddling
#             - 1 Eilyn's Frostrider
#             - 2 Hatchery Hunter
#             - 4 Iceknuckle Jotun
#             - 4 Lumbering Gruan
#             - 1 Moonlight Huntress
#             - 4 North-Wind Herald
#             - 2 Sapphire Dragon
#             - 2 Scouting Party
#             - 3 Shamanic Blast
#             - 4 Slope Sergeant
# [ 63/ 99] Processing file ss061.png...
#             - 2 Speardiver
#             - 3 Thunderstrike Dragon
#             - 4 Adaptive Predator
#             - 4 Araktodon
#             - 4 Bellowing Thunderfoot
#             - 4 Elysian Trailblazer
#             - 2 Enraged Araktodon
#             - 4 Hooru Teachings
#             - 4 Icequake
#             - 2 Mistveil Drake
#             - 1 Novice Herdrider
#             - 2 Rimescale Draconus
# [ 64/ 99] Processing file ss062.png...
#             - 1 Eilyn, Queen of the Wilds
#             - 3 Surveying Mantasaur
#             - 3 Channel the Tempest
#             - 1 Shadow Sigil
#             - 4 Amethyst Monument
#             - 4 Amethyst Waystone
#             - 4 Affliction
#             - 1 Arachnophobia
#             - 4 Blood Beetle
#             - 4 Brash Shorthorn
#             - 1 Brash Shorthorn
#             - 4 Dark Return
# [ 65/ 99] Processing file ss063.png...
#             - 4 Direfang Spider
#             - 4 Fallen Oni
#             - 1 Fallen Oni
#             - 4 Ghostform
#             - 1 Ghostform
#             - 4 Grenamender
#             - 3 Harbinger's Bite
#             - 3 Horrifying Helm
#             - 4 Jack's Knife
#             - 2 Jack's Knife
#             - 4 Lock Horns
#             - 3 Pilfer
# [ 66/ 99] Processing file ss064.png...
#             - 4 Sabotage
#             - 1 Sewer Sludge
#             - 4 Slumbering Stone
#             - 4 Spitefeeder
#             - 4 Suffocate
#             - 4 Swear Vengeance
#             - 4 Tock Tick
#             - 4 Trusty Revolver
#             - 1 Vara's Intervention
#             - 2 Wisplight
#             - 2 Abduct
#             - 3 Afterimage
# [ 67/ 99] Processing file ss065.png...
#             - 4 Annihilate
#             - 4 Argenport Instigator
#             - 2 Back-Alley Delinquent
#             - 2 Battlefield Scavenger
#             - 4 Cabal Cutthroat
#             - 4 Cabal Slasher
#             - 4 Cowardice
#             - 2 Cull the Deck
#             - 4 Dark Wisp
#             - 4 Dark Wisp
#             - 4 Devour
#             - 1 Fenris Nightshade
# [ 68/ 99] Processing file ss066.png...
#             - 4 Flashy Duelist
#             - 1 Flashy Duelist
#             - 3 Grenadin Bellower
#             - 1 Grenadin Bellower
#             - 2 Infused Strike
#             - 4 Lethrai Ranger
#             - 4 Lethrai Target Caller
#             - 4 Longshot Marksman
#             - 4 Lunging Wisp
#             - 1 Miris Nightshade
#             - 4 Piercing Grief
#             - 4 Rapid Shot
# [ 69/ 99] Processing file ss067.png...
#             - 1 Scare
#             - 4 Scavenging Vulture
#             - 2 Sleeping Draught
#             - 1 Sleeping Draught
#             - 4 Sporefolk
#             - 2 Territorial Elf
#             - 4 Threaten
#             - 1 Threaten
#             - 4 Unseen Agent
#             - 4 Vampire Bat
#             - 4 Vara's Favor
#             - 1 Vara's Favor
# [ 70/ 99] Processing file ss068.png...
#             - 4 Venomfang Dagger
#             - 4 Amethyst Acolyte
#             - 4 Amethyst Ring
#             - 4 Auric Interrogator
#             - 3 Banished Umbren
#             - 4 Beastcaller's Amulet
#             - 4 Blackguard Sidearm
#             - 1 Cabal Countess
#             - 3 Cat Burglar
#             - 2 Coronal Umbren
#             - 1 Coronal Umbren
#             - 1 Daggerclaw Howler
# [ 71/ 99] Processing file ss069.png...
#             - 4 Desperado
#             - 4 Devouring Shadow
#             - 4 Direwood Beastcaller
#             - 4 Duskcaller
#             - 4 Execute
#             - 4 Extract
#             - 3 Hair-Trigger Pistol
#             - 1 Hair-Trigger Pistol
#             - 4 Lethrai Memory-Keeper
#             - 1 Lethrai Memory-Keeper
#             - 4 Lethrai Nightblade
#             - 4 Lifedrinker
# [ 72/ 99] Processing file ss070.png...
#             - 4 Madness
#             - 3 Maimed Watchwing
#             - 1 Means to an End
#             - 4 Plague
#             - 3 Prickly Grenadin
#             - 4 Ravenous Thornbeast
#             - 4 Sadistic Valkyrie
#             - 4 Scheme
#             - 2 Shadowlands Guide
#             - 2 Shadowstalker
#             - 4 Skeeter
#             - 4 Sorrow's Shroud
# [ 73/ 99] Processing file ss071.png...
#             - 2 Sporebreath
#             - 4 Spur On
#             - 1 Spur On
#             - 1 Surgeon's Saw
#             - 2 Surgeon's Saw
#             - 1 Torrent of Spiders
#             - 4 Trigger-Happy
#             - 1 Umbren Deathwatcher
#             - 3 Xenan Cultist
#             - 1 Xenan Cultist
#             - 4 Xenan Destroyer
#             - 1 Xenan Destroyer
# [ 74/ 99] Processing file ss072.png...
#             - 4 Back-Alley Bouncer
#             - 1 Back-Alley Bouncer
#             - 4 Cabal Bludgeoner
#             - 4 Cabal Recruiter
#             - 3 Corrupted Umbren
#             - 4 Cripple
#             - 4 Deathstrike
#             - 1 Devious Drone
#             - 4 Dueling Pistols
#             - 4 Extinguish
#             - 4 Final-Shot Rioter
#             - 4 Hatecleaver
# [ 75/ 99] Processing file ss073.png...
#             - 2 Holdup
#             - 2 Impending Doom
#             - 1 Kyrex Coach Driver
#             - 4 Lethrai Falchion
#             - 4 Memory Dredger
#             - 4 Minotaur Lighthoof
#             - 1 Minotaur Lighthoof
#             - 4 Relentless Gorehorn
#             - 4 Savage Stranger
#             - 4 Soul Collector
#             - 4 Stonescar Magus
#             - 1 Stonescar Magus
# [ 76/ 99] Processing file ss074.png...
#             - 2 Street Leecher
#             - 4 Subvert
#             - 3 Vainglory Patrol
#             - 4 Vile Varmint
#             - 4 Xenan Fanatic
#             - 2 Ashara, the Deadshot
#             - 4 Colony Matron
#             - 4 Cover of Darkness
#             - 2 Grasping at Shadows
#             - 4 Grimy Alp-luachra
#             - 1 Headsman's Axe
#             - 4 Lethrai Bladewhirl
# [ 77/ 99] Processing file ss075.png...
#             - 1 Lurking Sanguar
#             - 4 Merciless Stranger
#             - 2 Moonlit Gargoyle
#             - 2 Oblivion Spike
#             - 1 Obrak, the Feaster
#             - 1 Stonescar Scrapper
#             - 4 Stray into Shadow
#             - 1 The End is Near
#             - 4 Triggerman
#             - 1 Triggerman
#             - 2 Umbren Coaxer
#             - 1 Umbren Reaper
# [ 78/ 99] Processing file ss076.png...
#             - 4 Umbren Thirster
#             - 2 Argenport Ringmaster
#             - 3 Cut Ties
#             - 4 Direwood Prowler
#             - 1 Direwood Prowler
#             - 4 Direwood Rampager
#             - 3 Drifting Death
#             - 2 Finback Komonat
#             - 2 Gunrustler
#             - 4 Horsesnatcher Bat
#             - 4 Slimespitter Slug
#             - 4 Spirit Drain
# [ 79/ 99] Processing file ss077.png...
#             - 1 Azindel's Gift
#             - 4 Cabal Rogue
#             - 1 Cabal Rogue
#             - 1 Dangerous Bargain
#             - 4 Inspire Obedience
#             - 2 Repulsive Gorger
#             - 4 Shadowlands Feaster
#             - 4 Sleepless Night
#             - 1 Umbren Occluder
#             - 1 Vara, Fate-Touched
#             - 4 Praxis Banner
#             - 1 Praxis Banner
# [ 80/ 99] Processing file ss078.png...
#             - 4 Seat of Impulse
#             - 4 Alluring Ember
#             - 4 Noble Firemane
#             - 4 Purify
#             - 1 Purify
#             - 4 Waker of Ancients
#             - 4 Champion of Impulse
#             - 4 Journeyman Armorer
#             - 3 Magus of Celerity
#             - 1 Mysterium Orb
#             - 4 Brilliant Discovery
#             - 2 Brilliant Discovery
# [ 81/ 99] Processing file ss079.png...
#             - 4 Clever Stranger
#             - 4 Diogo Málaga
#             - 4 Monolith Guardian
#             - 4 Sandglass Juggernaut
#             - 2 Shatterglass Mage
#             - 4 Talir's Choice
#             - 1 Talir's Choice
#             - 4 Workshop Forge
#             - 1 Heart of the Vault
#             - 1 Moment of Creation
#             - 4 Sandglass Sentinel
#             - 4 Rakano Banner
# [ 82/ 99] Processing file ss080.png...
#             - 4 Seat of Glory
#             - 4 Champion of Glory
#             - 1 Ijin's Choice
#             - 2 Rakano Artisan
#             - 1 Rakano Artisan
#             - 4 Crownwatch Deserter
#             - 4 Sower of Dissent
#             - 4 Sword of Icaria
#             - 1 Whirling Duo
#             - 4 Battleblur Centaur
#             - 4 Longhorn Sergeant
#             - 1 Longhorn Sergeant
# [ 83/ 99] Processing file ss081.png...
#             - 4 Renegade Valkyrie
#             - 1 Renegade Valkyrie
#             - 3 Righteous Fury
#             - 1 Rise to the Challenge
#             - 4 Field Captain
#             - 1 Field Captain
#             - 4 Jekk, the Bounty Hunter
#             - 1 Starsteel Daisho
#             - 4 Combrei Banner
#             - 4 Seat of Progress
#             - 4 Awakened Student
#             - 4 Desert Marshal
# [ 84/ 99] Processing file ss082.png...
#             - 4 Jaril, Amaran Ghostblade
#             - 4 Safe Return
#             - 1 Safe Return
#             - 4 Combrei Emissary
#             - 4 Combrei Healer
#             - 1 Combrei Healer
#             - 1 Shush
#             - 1 Stand Together
#             - 4 Vodakhan's Staff
#             - 4 Copperhall Elite
#             - 1 Enlightened Stranger
#             - 4 Karmic Guardian
# [ 85/ 99] Processing file ss083.png...
#             - 1 Stronghold's Visage
#             - 1 Champion of Progress
#             - 4 Minotaur Ambassador
#             - 1 Siraf's Choice
#             - 4 Elysian Banner
#             - 4 Seat of Wisdom
#             - 1 Derry Cathain, Ripclaw Rider
#             - 4 Storm Lynx
#             - 4 Twinning Ritual
#             - 4 Amaran Camel
#             - 4 False Prince
#             - 4 Pteriax Hatchling
# [ 86/ 99] Processing file ss084.png...
#             - 4 Avisaur Patriarch
#             - 1 Champion of Wisdom
#             - 1 Cirso's Choice
#             - 2 Crystalline Chalice
#             - 4 Nesting Avisaur
#             - 3 Scaletender
#             - 1 Cirso, the Great Glutton
#             - 3 Hunting Pteriax
#             - 1 Fortunate Stranger
#             - 4 Hooru Banner
#             - 4 Seat of Order
#             - 4 Bring Down
# [ 87/ 99] Processing file ss085.png...
#             - 2 Kothon, the Far-Watcher
#             - 4 Vision of Austerity
#             - 4 Aerialist Trainer
#             - 4 Eilyn's Choice
#             - 1 Eilyn's Choice
#             - 4 Hooru Pacifier
#             - 4 Spellshield Architect
#             - 2 Long Live the Queen
#             - 4 Master's Lesson
#             - 4 Shelterwing Rider
#             - 4 Shield Bash
#             - 3 Champion of Order
# [ 88/ 99] Processing file ss086.png...
#             - 4 Duelist's Blade
#             - 1 Duelist's Blade
#             - 4 Highwind Glider
#             - 4 Kosul Brigade
#             - 3 Meditative Stranger
#             - 2 Nostrix, Lord of Visions
#             - 4 Argenport Banner
#             - 4 Seat of Vengeance
#             - 4 Auric Bully
#             - 4 Auric Vigilante
#             - 4 Bloodletter
#             - 3 Rooftop Vigilante
# [ 89/ 99] Processing file ss087.png...
#             - 4 Slay
#             - 1 Slay
#             - 4 Stonepowder Alchemist
#             - 3 Champion of Vengeance
#             - 4 Sanguine Sword
#             - 1 Pyre Adept
#             - 4 Streetwise Informant
#             - 2 Inquisitor Makto
#             - 2 Knight of Sorrow
#             - 4 Rolant's Choice
#             - 1 Rolant's Choice
#             - 4 Tavrod, Auric Broker
# [ 90/ 99] Processing file ss088.png...
#             - 4 Valkyrie Denouncer
#             - 1 Valkyrie Denouncer
#             - 1 Grinva, Judge of Battles
#             - 4 Seat of Fury
#             - 4 Skycrag Banner
#             - 1 Skycrag Banner
#             - 4 Champion of Fury
#             - 4 Kaleb's Choice
#             - 1 Kaleb's Choice
#             - 4 Rockslide
#             - 4 Clan Hero
#             - 2 Crunch, the Hoarder
# [ 91/ 99] Processing file ss089.png...
#             - 1 Vadius, Clan Father
#             - 2 Calderan Cradle
#             - 4 Hunter's Harpoon
#             - 4 Mortar
#             - 4 Storm Glider
#             - 4 Unexpected Results
#             - 2 Bloodthirsty Brawler
#             - 2 Iceberg Warchief
#             - 4 Towering Stranger
#             - 1 Knucklebones
#             - 4 Topaz Drake
#             - 1 Molot & Nakova
# [ 92/ 99] Processing file ss090.png...
#             - 4 Decimate
#             - 1 Crest of Cunning
#             - 4 Feln Banner
#             - 4 Seat of Cunning
#             - 4 Twilight Raptor
#             - 4 Gorgon Swiftblade
#             - 1 Gorgon Swiftblade
#             - 4 Haunting Scream
#             - 3 Rindra's Choice
#             - 1 Feln Bloodcaster
#             - 4 Gorgon Fanatic
#             - 2 Recurring Nightmare
# [ 93/ 99] Processing file ss091.png...
#             - 3 Skywalk Enforcer
#             - 4 Trickster's Cloak
#             - 1 Trickster's Cloak
#             - 1 Ancient of the Ice Caves
#             - 4 Cabal Spymaster
#             - 4 Feeding Time
#             - 1 Feeding Time
#             - 4 Champion of Cunning
#             - 2 Spell Swipe
#             - 1 Spell Swipe
#             - 1 Snowcrush Animist
#             - 4 Seat of Chaos
# [ 94/ 99] Processing file ss092.png...
#             - 4 Stonescar Banner
#             - 1 Stonescar Banner
#             - 4 Combust
#             - 2 Hair-Trigger Stranger
#             - 4 Obsidian Golem
#             - 4 Quarry
#             - 2 Treachery
#             - 1 Champion of Chaos
#             - 3 Recycler
#             - 1 Bandit Queen
#             - 2 Black Iron Manacles
#             - 1 Stonescar Pickaxe
# [ 95/ 99] Processing file ss093.png...
#             - 3 Jekk's Choice
#             - 1 Runic Revolver
#             - 4 Warband Chieftain
#             - 1 Infernal Tyrant
#             - 3 Smuggler's Stash
#             - 4 Seat of Mystery
#             - 4 Xenan Banner
#             - 4 Bloodcall Invocation
#             - 4 Blistersting Wasp
#             - 4 Mitotic Wisp
#             - 4 Vara's Choice
#             - 1 Vara's Choice
# [ 96/ 99] Processing file ss094.png...
#             - 1 Ayan, the Abductor
#             - 1 Banish
#             - 4 Shadowlands Bonepicker
#             - 4 Cruciation
#             - 1 Duskwalker
#             - 4 Katra, the Devoted
#             - 1 Mask of Torment
#             - 1 Preserver of Dualities
#             - 4 Xenan Augury
#             - 2 Xenan Augury
#             - 4 Xenan Cupbearer
#             - 4 Bloodcall Invoker
# [ 97/ 99] Processing file ss095.png...
#             - 4 Champion of Mystery
#             - 1 Siphon Vitality
#             - 4 Prophetic Stranger
#             - 4 Triumphant Stranger
#             - 4 Nictotraxian
#             - 4 Diplomatic Seal
#             - 4 Spiked Helm
#             - 4 Stranger's Mark
#             - 2 Family Charter
#             - 4 Horus Traver
#             - 1 Veteran Strategist
#             - 4 Worn Shield
# [ 98/ 99] Processing file ss096.png...
#             - 4 Argenport Stranger
#             - 4 Combrei Stranger
#             - 4 Daze
#             - 4 Elysian Stranger
#             - 4 Feln Stranger
#             - 4 Hooru Stranger
#             - 1 Hooru Stranger
#             - 1 Petition
#             - 4 Praxis Stranger
#             - 4 Rakano Stranger
#             - 1 Recon Tower
#             - 4 Reunite
# [ 99/ 99] Processing file ss097.png...
#             - 4 Skycrag Stranger
#             - 4 Stonescar Stranger
#             - 4 Xenan Stranger
#             - 4 Alchemical Blast
#             - 1 Alchemical Blast
#             - 1 Disrupt
#             - 4 Forsworn Stranger
#             - 2 Momentum Builder
#             - 2 Rotorcycle
#             - 4 Caiphus, Wandering King
# [ERROR] Problem identifying card 11 in screenshot ss097.png!
# [ERROR] Problem identifying card 12 in screenshot ss097.png!
# CPU times: user 9min 7s, sys: 2.87 s, total: 9min 10s
# Wall time: 9min

# %%
my_collection=[]
for card in library:
    if library[card]['owned']>0:
        my_collection.append('{} {} (Set{} #{})'.format(library[card]['owned'],
                                                        card,
                                                        library[card]['set'],
                                                        library[card]['id']))
with open(collection_file,'w') as f:
    f.writelines([card+'\n' for card in my_collection])

# %% [markdown]
# Errors are to be expected at the last few cards, where there is actually no card on the screenshot.

# %%
errors
# Out:
# ['[ERROR] Problem identifying card 11 in screenshot ss097.png!',
#  '[ERROR] Problem identifying card 12 in screenshot ss097.png!']
