# %% [markdown]
# # Eternal Card Extractor

# %% [markdown]
# ## Section A: Make sure you have the required python 3 modules
# This script was built on Python 3.x and uses pyautogui and opencv 3.4.2. I think the rest of the default Python 3 modules are safe. If the cells below throw errors, you may have problems.

# %%
import sys
assert sys.version[0]=='3'

# %%
import cv2
assert cv2.__version__=='3.4.2'
    # cv2 versions above 3.4.2 do not seem to have xfeatures2d.SIFT methods directly available.
    # When in doubt, force the installation of version 3.4.2.16. I used
    #   pip3 install --user opencv-python==3.4.2.16
    #   pip3 install --user opencv-contrib-python==3.4.2.16
    # Both opencv-python and open-contrib-python seemed to be needed for SIFT to work.

# %%
import pyautogui
import pickle
import gzip

# %% [markdown]
# ## Section B: Grab screenshots of your card collection
# For this section, get Eternal running (maximized is easier) and head to the first screen of your card collection. Afterwards Alt-Tab back to this Jupyter notebook, make sure it is unmaximized and in a position that leaves Eternal visible on the top left corner (so that Python can simulate a click on the Eternal client and bring it to the foreground to take the screenshots), and run the cells below.
#
# (DISCLAIMER: I did not actually run the Section B code from this Jupyter notebook - I ran it from the command line using a script because I do not have Jupyter on the machine where I have Eternal installed. The script I did use is also available on the github repo. Be careful in any case: the script for reasons unknown generates two screenshots of the first page of the collection, which is ok but meeses up the number of cards owned of those cards. If you end up with duplicate screenshots, clean up!)

# %%
import pyautogui
import PIL
from PIL import ImageChops
import numpy as np
import time

# %%
screenshots_folder='./Screenshots/'
    # Where to save screenshots
max_screenshots=150
    # Stop after so many screenshots if the end condition is not met
avg_diff_cutoff=5
    # Screenshot average pixel value to consider two screenshots identical
same_img_limit=3
    # Number of identical sequential screenshots to determine the end of the collection has been reached
eternal_x,eternal_y=10,10
    # Position to click on in order to bring Eternal to the foreground
next_x,next_y=0.855*pyautogui.size()[0],0.525*pyautogui.size()[1]
    # Position to click to move to the next collection page

# %%
remove_new_aura=False
    # Flag signaling whether the shinyness around new cards should be removed
    # before taking the screenshots
sep_x,sep_y=int(0.1218*pyautogui.size()[0]),int(0.3852*pyautogui.size()[1])
    # Represents the distances between equivalent positions of cards on the screenshot,
    # i.e., 'top left to top left' or 'center to center', or whatever
crd_x,crd_y=int(0.1730*pyautogui.size()[0]),int(0.2120*pyautogui.size()[1])
    # Represents the top left corner of the feature extraction box of the first card
pos_lst=[ (crd_x+n_x*sep_x,crd_y+n_y*sep_y)
          for n_y in range(2) for n_x in range(6) ]
    # Represent a position in each of the 12 cards so that the script can remove the 'NEW' aura

# %%
pyautogui.click(eternal_x,eternal_y)

cnt_ss=0
cnt_page=0
cnt_same=0
old_screenshot=PIL.Image.new('RGB',pyautogui.size())
while (cnt_ss<max_screenshots) and (cnt_same<same_img_limit):
    cnt_ss=cnt_ss+1
    if remove_new_aura:
        time.sleep(0.1)
        for card_x,card_y in pos_lst:
            pyautogui.moveTo(card_x,card_y)
        pyautogui.moveTo(next_x,next_y)
    new_screenshot=pyautogui.screenshot()
    if np.asarray(ImageChops.difference(old_screenshot,new_screenshot)).mean()>avg_diff_cutoff:
        cnt_same=0
        cnt_page=cnt_page+1
        new_screenshot.save(screenshots_folder+'ss{:03d}.png'.format(cnt_page))
        old_screenshot=new_screenshot
    else:
        cnt_same=cnt_same+1
    pyautogui.click(next_x,next_y)

# %% [markdown]
# ## Section C: Identify card collection

# %% [markdown]
# ### Section C.1: Load card artwork features

# %% [markdown]
# The library is based on the one in Eternal Warcry - thanks for allowing me to use it for this project!
#
# The pickle module is very nice but can lead to incompatibilities. If it cannot unpickle the library, let me know so that I can think of an alternative way of serializing it.

# %%
import os
import pickle
import gzip

# %%
library_local='./Libraries/'
    # Location of the pickled gzipped libraries with the artwork descriptors already calculated
    # that I prepared so that you don't have to.
library_root='card_library_set_'
    # Expected name of the library files - in case any other files rnd up in the same folder.

# %%
library={}
for set_library in os.listdir(library_local):
    if library_root in set_library:
        with gzip.open(library_local+set_library,'rb') as library_file:
            library.update(pickle.load(library_file))

# %% [markdown]
# ### Section C.2: Process screenshots

# %%
import pyautogui
import cv2
import os

# %%
img_w,img_h=int(0.0479*pyautogui.size()[0]),int(0.1130*pyautogui.size()[1])
    # Size in pixels of the box used to extract features from.
    # Limited by either the resolution of your screen or that of the card artwork.
nfeatures=50
    # Number of features to extract from each box. 50 seems to work well.

    # This area has some upside potential by the way - identifying less features based
    # on lower resolution boxes would speed up the process and produce a smaller
    # card library file. To be explored.
sift=cv2.xfeatures2d.SIFT_create(nfeatures=nfeatures)

# %% [markdown]
# The functions below seem fairly common for this specific purpose. My understanding of them is incomplete, but the first one seems to return the good matching features between two descriptor sets (and will be used once between the target and each of the possible option images), and the second one seems to compute how may of the total matching features that were considered good came from each classification option (and will be used once, after all of the options have been evaluated).
#
# The option that generated the highest number of good matching features is the most likely one.

# %%
def knn_match(des1, des2, nn_ratio=0.7):
    index_params = dict(algorithm = 0, trees = 5)
    search_params = dict(checks = 50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(des1, des2, k=2)
    good = []
    for m, n in matches:
        if m.distance < nn_ratio * n.distance:
            good.append(m)
    return good

def knn_clasif(good_matches):
    logprobs=[]
    best_template, highest_logprob = None, 0.0
    sum_good_matches = sum([len(gm) for gm in good_matches])
    for i, gm in enumerate(good_matches):
        logprob = len(gm)/sum_good_matches
        logprobs.append(logprob)
        if logprob > highest_logprob:
            highest_logprob = logprob
            best_template = i
    return best_template,logprobs

# %% [markdown]
# The parameters below define the places in the screenshots where we will extract image boxes and number owned diamonds from. Plenty of options would be available; I went for estimating:
# - The distance between cards (sep_x,sep_y), which when aplied to the position of the top left corner of the first image box (crd_x,crd_y) generates the boxes that will be used to extract owned card features (pos_lst)
# - The distance between the cards (the same sep_x,sep_y) and the horizontal distance between the ownership diamonds (sep_cnt), which when applied to the position of the center of the second diamond (the first one is a given - you always have at least one card of those present in the screenshots) of the top left card (cnt_x,cnt_y) generates the points to check if an ownership diamond is present (cnt_lst). This test is done against a cutoff of 100, but the actual values measured on the screenshots were 330 on yes-diamond and 15 on no-diamond
#
# There is another notebook in the repo to help finetune these parameters.

# %%
screenshots_folder='./Screenshots/'
collection_file='./my_collection.txt'

sep_x,sep_y=int(0.1218*pyautogui.size()[0]),int(0.3852*pyautogui.size()[1])
    # Represents the distances between equivalent positions of cards on the screenshot,
    # i.e., 'top left to top left' or 'center to center', or whatever
crd_x,crd_y=int(0.1730*pyautogui.size()[0]),int(0.2120*pyautogui.size()[1])
    # Represents the top left corner of the feature extraction box of the first card
pos_lst=[ (crd_x+n_x*sep_x,crd_y+n_y*sep_y,img_w,img_h)
          for n_y in range(2) for n_x in range(6)]
    # Represent the list of feature extraction boxes of the 12 cards

sep_cnt=int(0.013*pyautogui.size()[0])
    # Represents the horizontal distance between equivalent positions of diamods on the screenshot
    # i.e., 'top left to top left' or 'center to center', or whatever
cnt_x,cnt_y=int(0.1917*pyautogui.size()[0]),int(0.1463*pyautogui.size()[1])
    # Represents the center of the second ownership diamond of the first card
cnt_lst=[ [(cnt_x+n_x*sep_x+n_cnt*sep_cnt,cnt_y+n_y*sep_y) for n_cnt in range(3)]
          for n_y in range(2) for n_x in range(6)]
    # Represents the center of the second, third, and fourth diamonds of the 12 cards

owned_threshold=100
    # Threshold to determine whether at the point there is a yes-diamond or no-diamond.
    # The actual numbers are 330 for yes-diamond and 15 for no-diamond

# %% [markdown]
# The script extracts each card in each screenshot of the collection, compares its features with those of all the cards in the library, and finds the best match.
#
# It can be made much faster by identifying additional features from the cards, such as power requirements profile, cost, or attack; these can then be used to narrow the search for the target card, which would also allow to reduce the size of the feature extraction boxes and the number of features being extracted from each box.
#
# I also tried text extraction, but tesseract did not work well on the card names, at least not on my low resolution screenshots. That however does not mean it cannot be used to speed up the identification process, as long as the extracted gibberish is consistent.
#
# To be explored.

# %%
# %%time

list_cards=list(library)
for card in library:
    library[card]['owned']=0
errors=[]
tot=len(os.listdir(screenshots_folder))
cnt=0
for ss_file in sorted(os.listdir(screenshots_folder)):
    cnt=cnt+1
    print('[{:3d}/{:3d}] Processing file {}...'.format(cnt,tot,ss_file))
    if ss_file[-3:]=='png':
        screenshot=cv2.imread(screenshots_folder+ss_file)
        for i in range(12):
            l,t,w,h=pos_lst[i]
            target=cv2.resize(screenshot[t:t+h,l:l+w],(img_w,img_h))
            try:
                _,descriptors=sift.detectAndCompute(target,None)
                list_good_matches=[]
                for card in library:
                    list_good_matches.append(knn_match(library[card]['descriptors'],descriptors))
                best_match,probs=knn_clasif(list_good_matches)
                num_owned=1+sum([ screenshot[c[1],c[0],:].sum()>owned_threshold for c in cnt_lst[i]])
                print(12*' '+'- {} '.format(num_owned)+list_cards[best_match])
                library[list_cards[best_match]]['owned']=min(4,library[list_cards[best_match]]['owned']+num_owned)
            except:
                errors.append('[ERROR] Problem identifying card {:2d} in screenshot {}!'.format(i+1,ss_file))
                print(errors[-1])
                pass
# Out:
# [  1/117] Processing file ss001.png...
#             - 4 Seek Power
#             - 1 Fire Sigil
#             - 4 Granite Monument
#             - 1 Granite Monument
#             - 4 Granite Waystone
#             - 4 Shugo Standard
#             - 4 Helpful Doorbot
#             - 4 Melt Down
#             - 1 Trail Stories
#             - 4 Bore
#             - 1 Bottoms Up
#             - 4 Cautious Traveler
# [  2/117] Processing file ss002.png...
#             - 4 Drifter
#             - 4 Firemane Cub
#             - 4 Forge Wolf
#             - 4 Grenadin Drone
#             - 4 Heavy Axe
#             - 4 Hidden Shiv
#             - 1 Hidden Shiv
#             - 4 Iceberg Frontrunner
#             - 1 Kaleb's Intervention
#             - 4 Light 'em Up
#             - 2 Mindfire
#             - 4 On the Hunt
# [  3/117] Processing file ss003.png...
#             - 4 Oni Dragonsmith
#             - 4 Oni Ronin
#             - 4 Pummel
#             - 4 Pyroknight
#             - 4 Rambot
#             - 4 Research Assistant
#             - 4 Ruin
#             - 1 Ruin
#             - 4 Ruthless Stranger
#             - 3 Scrap Hound
#             - 4 Signal Flare
#             - 4 Softfoot Burglar
# [  4/117] Processing file ss004.png...
#             - 1 Softfoot Burglar
#             - 4 Temper
#             - 4 Ticking Grenadin
#             - 4 Torch
#             - 1 Urn of Choking Embers
#             - 4 Warhelm
#             - 4 Young Gun
#             - 4 Ankle Cutter
#             - 4 Bladekin Apprentice
#             - 4 Blazing Renegade
#             - 4 Blinkwolf
#             - 4 Cauldron Cookbook
# [  5/117] Processing file ss005.png...
#             - 1 Charchain Flail
#             - 4 Conflagrate
#             - 2 Consuming Flames
#             - 3 Disassembler
#             - 1 Factory Quota
#             - 3 Firemane Lioness
#             - 4 Flame Blast
#             - 3 Flamefang Charmer
#             - 1 Flamefang Charmer
#             - 2 Grenarender
#             - 4 Hotblood Barbarian
#             - 4 Into the Furnace
# [  6/117] Processing file ss006.png...
#             - 4 Kaleb's Favor
#             - 2 Kaleb's Favor
#             - 2 Oni Cavediver
#             - 4 Oni Forgemaster
#             - 4 Ornate Katana
#             - 4 Piercing Shot
#             - 4 Pyre Adept
#             - 1 Pyre Adept
#             - 4 Rakano Outlaw
#             - 4 Rampage
#             - 4 Ruination Sledge
#             - 1 Ruination Sledge
# [  7/117] Processing file ss007.png...
#             - 4 Smith's Hammer
#             - 1 Song of War
#             - 4 Spark Hatcher
#             - 4 Trick Shot
#             - 4 Tripwire Grenadin
#             - 4 Unpredictable Outlaw
#             - 2 Yeti Sage
#             - 4 Assembly Line
#             - 4 Backpacker's Machete
#             - 4 Cinder Yeti
#             - 4 Fevered Scout
#             - 3 Fireheart Recruit
# [  8/117] Processing file ss008.png...
#             - 4 First-Shot Rioter
#             - 4 Frontier Bard
#             - 1 Grandfather's Axe
#             - 4 Granite Acolyte
#             - 1 Granite Acolyte
#             - 4 Granite Ring
#             - 1 Granite Ring
#             - 4 Grenade
#             - 1 Grenade
#             - 4 Hipshot
#             - 1 Honor the Ancestors
#             - 4 Hoof Slash
# [  9/117] Processing file ss009.png...
#             - 2 Ixtun Merchant
#             - 4 Jawbone Hatchet
#             - 4 Kindle
#             - 4 Lazy Firemane
#             - 2 Manufacture
#             - 4 Oni Eulogist
#             - 4 Oni Quartermaster
#             - 4 Praxis Outlaw
#             - 4 Rakano Flagbearer
#             - 4 Rally
#             - 4 Rebel Sharpshooter
#             - 2 Refracted Sentinel
# [ 10/117] Processing file ss010.png...
#             - 3 Ruincrawler Yeti
#             - 3 Rusty Grenamotive
#             - 2 Scrap Heap
#             - 2 Shogun's Scepter
#             - 4 Sparkbot
#             - 4 Stonescar Excavator
#             - 4 Stoneshaker
#             - 4 Temple Raider
#             - 1 Toppletower
#             - 3 Tumblebang
#             - 4 Twinbarrel
#             - 2 Twinbarrel
# [ 11/117] Processing file ss011.png...
#             - 4 Warpainter
#             - 4 Won't Be Pretty
#             - 2 Ancient Defenses
#             - 4 Arms Enthusiast
#             - 4 Audacious Bandit
#             - 3 Audacious Bandit
#             - 4 Barbarian Camp
#             - 1 Bladerang
#             - 4 Burn Out
#             - 4 Centaur Outrider
#             - 4 Clan Wallbreaker
#             - 2 Cloud of Ash
# [ 12/117] Processing file ss012.png...
#             - 1 Cloud of Ash
#             - 4 Crimson Firemaw
#             - 3 Criva, the Crimson Scythe
#             - 1 Furnace Mage
#             - 1 Gilded Flames
#             - 4 Grenadin Cannoneer
#             - 4 Groundbreaker
#             - 4 Guerrilla Fighter
#             - 1 Hardsight Cyclops
#             - 3 Hellfire Oni
#             - 3 Iceberg Scattershot
#             - 3 Library Phoenix
# [ 13/117] Processing file ss013.png...
#             - 4 Magma Javelin
#             - 2 Magma Javelin
#             - 4 Morningstar
#             - 4 Outlands Brute
#             - 4 Outlands Sniper
#             - 4 Overheat
#             - 4 Rebel Illuminator
#             - 4 Recogulator
#             - 4 Reforge
#             - 3 Ruckus Rouser
#             - 4 Scalechannel Sorcerer
#             - 3 Spitfire
# [ 14/117] Processing file ss014.png...
#             - 2 Steelfang Chakram
#             - 2 Stonescar Sawed-Off
#             - 3 Surveilor
#             - 4 Swift Stranger
#             - 1 Swift Stranger
#             - 4 Thunderhoof Warrior
#             - 3 Wandering Forge
#             - 4 Welding Torch
#             - 4 Yushkov, the Usurper
#             - 4 Bait
#             - 3 Calderan Gunsmith
#             - 4 Centaur Raidleader
# [ 15/117] Processing file ss015.png...
#             - 4 Dustblind
#             - 4 Dusthoof Brawler
#             - 4 Fiery Fissure
#             - 4 Flash Fire
#             - 4 Gun Down
#             - 1 Gun Down
#             - 1 Hordeleader
#             - 4 Obliterate
#             - 4 Oni Striker
#             - 1 Parapet Sentry
#             - 4 Pit Fighter
#             - 4 Pouncing Drake
# [ 16/117] Processing file ss016.png...
#             - 4 Powderkeg Rider
#             - 3 Robobuddy
#             - 3 Staff of the Arch-Magister
#             - 4 Stonepowder Heretic
#             - 1 Stonepowder Heretic
#             - 2 Wildfire Censari
#             - 3 Barkeep's Friend
#             - 4 Cannonbearer
#             - 4 Crowd Favorite
#             - 1 End of the Barrel
#             - 4 Frontline Cyclops
#             - 3 General Izalio
# [ 17/117] Processing file ss017.png...
#             - 4 Hellfire Rifle
#             - 1 Oni Gunwright
#             - 4 Pyre Elemental
#             - 2 Shingane Captain
#             - 3 Stonescar Maul
#             - 3 Tempered Sentinel
#             - 4 Waystone Titan
#             - 2 Worldpyre Phoenix
#             - 4 Burning Glaive
#             - 1 Claw of the First Dragon
#             - 4 Core Scavenger
#             - 4 Final Shot
# [ 18/117] Processing file ss018.png...
#             - 1 Improvised Rubbler
#             - 2 Steelbound Dragon
#             - 1 Heroic Bravo
#             - 2 Kaleb, Uncrowned Prince
#             - 4 Magmatic Sentinel
#             - 1 Lavablood Goliath
#             - 1 Sindok, Rage Incarnate
#             - 1 Time Sigil
#             - 4 Amber Monument
#             - 4 Amber Waystone
#             - 4 Temple Standard
#             - 4 Sand Warrior
# [ 19/117] Processing file ss019.png...
#             - 4 Unearth the Past
#             - 3 Amaran Shoveler
#             - 4 Ancient Bauble
#             - 3 Araktodon Egg
#             - 4 Be Gone
#             - 4 Cult Aspirant
#             - 2 Entrancer
#             - 4 Envelop
#             - 4 Excavate
#             - 4 Excavation Assistant
#             - 1 Excavation Assistant
#             - 2 Gloaming Wisp
# [ 20/117] Processing file ss020.png...
#             - 4 Humbug
#             - 2 Humbug
#             - 4 Infinite Hourglass
#             - 1 Infinite Hourglass
#             - 4 Initiate of the Sands
#             - 1 Initiate of the Sands
#             - 4 Jibbering Jackal
#             - 4 Journey Guide
#             - 4 Lucky Prospector
#             - 4 Meditation
#             - 4 Ornamental Daggers
#             - 4 Predator's Instinct
# [ 21/117] Processing file ss021.png...
#             - 4 Sanctuary Priest
#             - 4 Scorpion
#             - 4 Silence
#             - 4 Slow
#             - 1 Slow
#             - 4 Staff of Speed
#             - 1 Staff of Speed
#             - 4 Training Ground
#             - 4 Water of Life
#             - 4 Accelerate
#             - 4 Bold Adventurer
#             - 2 Copper Conduit
# [ 22/117] Processing file ss022.png...
#             - 2 Cryptic Etchings
#             - 1 Cryptic Etchings
#             - 4 Disjunction
#             - 1 Dissociate
#             - 1 Ephemeral Wisp
#             - 3 Evelina, Valley Searcher
#             - 4 Find the Way
#             - 2 Forgotten Find
#             - 4 Friendly Wisp
#             - 3 Illumination Wisp
#             - 2 Last Rites
#             - 4 Learned Herbalist
# [ 23/117] Processing file ss023.png...
#             - 4 Living Example
#             - 3 Living Offering
#             - 1 Locust
#             - 3 Nocturnal Creeper
#             - 4 Oasis Seeker
#             - 4 Packbeast
#             - 4 Porcelain Mask
#             - 4 Power Stone
#             - 4 Refresh
#             - 1 Refresh
#             - 4 Resolute Monk
#             - 4 Sand Viper
# [ 24/117] Processing file ss024.png...
#             - 4 Sandglass Parma
#             - 4 Sandstorm
#             - 1 Sandstorm
#             - 4 Sauropod Wrangler
#             - 4 Sauropod Wrangler
#             - 3 Sustaining Harp
#             - 4 Synchronized Strike
#             - 1 Synchronized Strike
#             - 4 Talir's Favored
#             - 1 Talir's Favored
#             - 4 Teleport
#             - 4 Temple Scribe
# [ 25/117] Processing file ss025.png...
#             - 4 Trail Maker
#             - 4 Trail Runner
#             - 1 Voice of the Speaker
#             - 4 Xenan Initiation
#             - 4 Ageless Mentor
#             - 4 Amber Acolyte
#             - 4 Amber Ring
#             - 1 Auralian Merchant
#             - 4 Avirax Familiar
#             - 4 Awaken the Ages
#             - 1 Awaken the Ages
#             - 4 Baying Serasaur
# [ 26/117] Processing file ss026.png...
#             - 2 Clockroach
#             - 2 Dawnwalker
#             - 4 Decay
#             - 1 Decay
#             - 3 Deft Strike
#             - 4 Determined Stranger
#             - 4 Dilphex Stalker
#             - 4 Disciplined Amanera
#             - 4 Dispel
#             - 1 Dispel
#             - 1 Dune Phantom
#             - 2 Gear Master
# [ 27/117] Processing file ss027.png...
#             - 4 Gravetender
#             - 2 Initiation Bell
#             - 3 Lastlight Infusion
#             - 1 Lastlight Infusion
#             - 2 Lunar Magus
#             - 1 Mesmerized Moth
#             - 2 Moondial
#             - 4 Oasis Sanctuary
#             - 3 Premonition Wisp
#             - 2 Reliquary Raider
#             - 2 Sandcrawler
#             - 4 Scorpion Wasp
# [ 28/117] Processing file ss028.png...
#             - 4 Seasoned Spelunker
#             - 1 Secret Pages
#             - 2 Serene Excavator
#             - 4 Shepherd's Horn
#             - 4 Sirocco Elementalist
#             - 4 Spiteful Lumen
#             - 4 Unlock Potential
#             - 2 Unraveling Fanatic
#             - 4 Watchful Amanera
#             - 1 Wurmcalling
#             - 2 Ageless Sentinel
#             - 4 Ancient Lore
# [ 29/117] Processing file ss029.png...
#             - 4 Archive Curator
#             - 3 Beckoning Lumen
#             - 4 Bolster
#             - 4 Camp Physician
#             - 4 Devoted Theurge
#             - 1 Fantastic Revelation
#             - 4 Fierce Mosaraptor
#             - 2 Gathering Lights
#             - 4 Healer's Cloak
#             - 4 Hissing Spiketail
#             - 4 Horned Vorlunk
#             - 1 Horned Vorlunk
# [ 30/117] Processing file ss030.png...
#             - 1 Insatiable Serasaur
#             - 1 Insistent Automaton
#             - 4 Lost in the Mist
#             - 1 Lumen Attendant
#             - 3 Maddening Whisper
#             - 3 Marisen's Disciple
#             - 4 Memento Mori
#             - 1 Pompous Historian
#             - 4 Primeval Plover
#             - 1 Sandspitter
#             - 3 Sandspout Mirage
#             - 2 Sandstorm Titan
# [ 31/117] Processing file ss031.png...
#             - 1 Sirocco Glider
#             - 4 Snapping Brushstalker
#             - 2 Snapping Brushstalker
#             - 1 Steward of Prophecy
#             - 1 Stinging Wind
#             - 1 Stirring Sand
#             - 4 Striped Araktodon
#             - 1 Striped Araktodon
#             - 1 Temple Artisan
#             - 4 Timekeeper
#             - 4 Towertop Patrol
#             - 2 Twinfang Cobra
# [ 32/117] Processing file ss032.png...
#             - 1 Vault of the Praxis
#             - 4 Venom Rider
#             - 4 Viper's Bite
#             - 4 Wurmstone
#             - 4 Xenan Guardian
#             - 1 Xenan Obelisk
#             - 4 Amaran Archaeologist
#             - 2 Ancient Excavator
#             - 4 Awakened Sentinel
#             - 1 Awakened Sentinel
#             - 4 Battle-Tested Stranger
#             - 2 Confiscate
# [ 33/117] Processing file ss033.png...
#             - 2 First Watch
#             - 4 Fishing Dinoch
#             - 3 Frenzied Omnivore
#             - 3 Infused Guardian
#             - 4 Lumen Defender
#             - 2 Mistress of Light
#             - 4 Pensive Lumen
#             - 1 Pensive Lumen
#             - 4 Praxis Displacer
#             - 3 Sandbinder Sentinel
#             - 2 Striking Snake Formation
#             - 4 Time Weaver
# [ 34/117] Processing file ss034.png...
#             - 4 Towering Terrazon
#             - 4 Twinbrood Sauropod
#             - 3 Vital Arcana
#             - 4 Waystone Infuser
#             - 1 Waystone Infuser
#             - 2 Wurmic Chanter
#             - 4 Bury the Past
#             - 4 Humbug Swarm
#             - 4 Lumen Shepherd
#             - 4 Pack Hunt
#             - 4 Passage of Eons
#             - 4 Plated Goliath
# [ 35/117] Processing file ss035.png...
#             - 1 Plated Goliath
#             - 1 Powerbreach Sentinel
#             - 1 Sentinel's Might
#             - 1 Serasaur Bull
#             - 4 Timeworn Sentinel
#             - 1 Tomb Protector
#             - 4 Voyaging Lumen
#             - 4 Dormant Sentinel
#             - 4 Elysian Pathfinder
#             - 1 Elysian Pathfinder
#             - 3 Hall of Lost Kings
#             - 4 Hibernating Behemoth
# [ 36/117] Processing file ss036.png...
#             - 4 Pillar of Amar
#             - 1 Pillar of Amar
#             - 4 Predatory Carnosaur
#             - 2 Reality Shift
#             - 1 Reality Shift
#             - 4 Subterranean Sentry
#             - 1 Talir, Unbound
#             - 4 Tesya, Omen Shaper
#             - 4 Belching Behemoth
#             - 1 Belching Behemoth
#             - 2 Dinosaur Stampede
#             - 2 Intriguing Ancient
# [ 37/117] Processing file ss037.png...
#             - 3 Runic Protector
#             - 3 Talir, Who Sees Beyond
#             - 4 Scourstone Sentinel
#             - 4 Foraging Sauropod
#             - 1 Justice Sigil
#             - 2 Crownwatch Standard
#             - 2 Emerald Monument
#             - 4 Emerald Waystone
#             - 3 Endure
#             - 4 Crownwatch Squire
#             - 1 Defiance
#             - 4 Detain
# [ 38/117] Processing file ss038.png...
#             - 4 District Infantry
#             - 1 District Infantry
#             - 4 Elder's Feather
#             - 4 Finest Hour
#             - 1 Ironfist Faithful
#             - 4 Lingering Influence
#             - 4 Minotaur Oathkeeper
#             - 4 Oni Samurai
#             - 4 Peacekeeper's Helm
#             - 1 Rolant's Intervention
#             - 4 Sharpened Reflex
#             - 4 Spire Spellsword
# [ 39/117] Processing file ss039.png...
#             - 4 Steadfast Deputy
#             - 4 Steady Marshal
#             - 1 Svetya's Bravery
#             - 4 Tinker Apprentice
#             - 1 Unmoored Valkyrie
#             - 4 Valkyrie Aspirant
#             - 4 Arcane Defense
#             - 4 Argenport Soldier
#             - 3 Axe Sharpener
#             - 4 Barrel Through
#             - 1 Chancellor's Horn
#             - 4 Copperhall Herald
# [ 40/117] Processing file ss040.png...
#             - 2 Copperhall Herald
#             - 4 Copperhall Porter
#             - 2 Crackshot Fugitive
#             - 4 Crownwatch Longsword
#             - 4 Crownwatch Paladin
#             - 3 Eager Owlet
#             - 1 Eager Owlet
#             - 3 Fall Short
#             - 1 Hojan, Crownbreaker
#             - 4 Icaria, Valkyrie Captain
#             - 4 Inspire
#             - 3 Kosul Diplomat
# [ 41/117] Processing file ss041.png...
#             - 4 Master-at-Arms
#             - 4 Minotaur Grunt
#             - 4 Minotaur Grunt
#             - 2 Paladin Oathbook
#             - 4 Protect
#             - 1 Rampart Protector
#             - 4 Rebuke
#             - 4 Reinforce
#             - 2 Reinvigorate
#             - 1 Rilgon's Disciple
#             - 4 Rolant's Favor
#             - 1 Rolant's Favor
# [ 42/117] Processing file ss042.png...
#             - 4 Soaring Guard
#             - 4 Sparring Partner
#             - 4 Stalwart Silverwing
#             - 4 Strength of Many
#             - 4 Talon of Nostrix
#             - 4 Tinker
#             - 1 Tinker
#             - 4 Tinker Overseer
#             - 4 Tranquil Scholar
#             - 4 Vanquish
#             - 1 Wanted Poster
#             - 1 Workshop Tinker
# [ 43/117] Processing file ss043.png...
#             - 1 Workshop Tinker
#             - 3 Auric Herdward
#             - 4 Auric Sentry
#             - 4 Brightmace Paladin
#             - 4 Copperhall Bailiff
#             - 1 Copperhall Bracers
#             - 4 Copperhall Cudgel
#             - 4 Copperhall Marshal
#             - 4 Copperhall Shieldman
#             - 4 Emerald Acolyte
#             - 4 Emerald Ring
#             - 4 Fencing Master
# [ 44/117] Processing file ss044.png...
#             - 1 Fencing Master
#             - 1 Fur Hat
#             - 4 Gilded Glaive
#             - 4 Grit
#             - 4 Guard Dog
#             - 4 Herald of the Parliament
#             - 4 Hero of the People
#             - 4 Highbranch Sentry
#             - 2 Hooru Envoy
#             - 3 Kosul Battlemage
#             - 1 Kosul Elite
#             - 4 Kosul Recruit
# [ 45/117] Processing file ss045.png...
#             - 4 Longhorn Treasurer
#             - 4 Loyal Watchwing
#             - 2 Mark of Shame
#             - 4 Miner's Canary
#             - 1 Order of the Spire
#             - 2 Privilege of Rank
#             - 1 Privilege of Rank
#             - 3 Reinforced Baton
#             - 2 Rolant's Memorial
#             - 2 Rotorsmith
#             - 4 Saddle Up
#             - 4 Shard of the Spire
# [ 46/117] Processing file ss046.png...
#             - 1 Showdown
#             - 2 Signal Flag
#             - 4 Silverwing Familiar
#             - 2 Silverwing Smith
#             - 2 Spire Chaplain
#             - 4 Spirit Guide
#             - 2 Steel-Eyed Pistoleer
#             - 3 Tandem Watchwing
#             - 4 Tireless Stranger
#             - 1 Tireless Stranger
#             - 4 Treasury Guard
#             - 2 Unseen Commando
# [ 47/117] Processing file ss047.png...
#             - 4 Valkyrie Cadet
#             - 4 Valkyrie Enforcer
#             - 3 Valorous Stranger
#             - 1 Warrant Officer
#             - 1 Warrant Officer
#             - 3 Aerial Spotter
#             - 4 Armorsmith
#             - 4 Auric Runehammer
#             - 1 Auric Weaponsmith
#             - 1 Avigraft
#             - 4 Bronze Cuirass
#             - 1 Citywide Ban
# [ 48/117] Processing file ss048.png...
#             - 2 Copperhall Blessing
#             - 4 Copperhall Paladin
#             - 4 Copperhall Recruit
#             - 2 Copperhall Recruit
#             - 4 Crownwatch Cavalry
#             - 4 Crownwatch Press-Gang
#             - 1 Curse of Taxation
#             - 4 Frontier Confessor
#             - 4 Graceful Calligrapher
#             - 2 Ground Crew
#             - 4 Hammer of Might
#             - 4 Honor the Fallen
# [ 49/117] Processing file ss049.png...
#             - 3 Imperial Loyalist
#             - 4 Inquisitor's Blade
#             - 2 Ironclad Oath
#             - 1 Ironclad Oath
#             - 1 Lawman's Sidearm
#             - 4 Mantle of Justice
#             - 4 Peacekeeper's Prod
#             - 3 Pistolwhip
#             - 4 Rabblerouser
#             - 1 Rakano Sheriff
#             - 2 Sheriff Marley
#             - 3 Sheriff's Hat
# [ 50/117] Processing file ss050.png...
#             - 4 Shielded Shortbarrel
#             - 4 Silverwing Avenger
#             - 4 Sky Crew
#             - 4 Spiked Buckler
#             - 1 Spiritblade Stalker
#             - 4 Stalwart Shield
#             - 1 Valkyrie Bodyguard
#             - 4 Valkyrie Militant
#             - 1 Valkyrie Militant
#             - 4 Valkyrie Spireguard
#             - 4 Victor's Cry
#             - 2 Victor's Cry
# [ 51/117] Processing file ss051.png...
#             - 1 Amilli, Cloudmarshal
#             - 4 Broken Wing Brawler
#             - 4 Combrei Magister
#             - 4 Crownwatch Recruiter
#             - 3 Downfall
#             - 1 Harsh Rule
#             - 4 Hone
#             - 4 Hooru Fledgling
#             - 1 Hooru Fledgling
#             - 4 Minotaur Duelist
#             - 4 Mithril Mace
#             - 2 Rallying Banner
# [ 52/117] Processing file ss052.png...
#             - 3 Rampart Arbalest
#             - 1 Rampart Arbalest
#             - 4 Scepter of Nobility
#             - 3 Silverwing Commander
#             - 4 Throne Warden
#             - 4 Twinstrike Master
#             - 4 Aerialist's Khopesh
#             - 1 Aerialist's Khopesh
#             - 2 Augmented Form
#             - 4 Ceremonial Mask
#             - 1 Challenge by Law
#             - 4 Civic Peacekeeper
# [ 53/117] Processing file ss053.png...
#             - 1 Crownwatch Captain
#             - 4 Fourth-Tree Elder
#             - 3 Heirloom Blade
#             - 4 Horngrinder
#             - 1 Ironfist Archon
#             - 1 New Order Watchwing
#             - 4 Oathkeeper's Hammer
#             - 4 Prosecutor-at-Arms
#             - 1 Regent's Blade
#             - 1 Reyna, the Unwavering
#             - 4 Roosting Owl
#             - 4 Silverwing Purgeleader
# [ 54/117] Processing file ss054.png...
#             - 2 Tower Shield
#             - 2 Town Watchman
#             - 3 Valkyrie Arcanist
#             - 1 Valkyrie Wings
#             - 4 Watchwing Conscript
#             - 1 Aerial Attendant
#             - 1 Crown of Authority
#             - 3 Emerald Spear
#             - 4 Flight Lieutenant
#             - 1 Leave a Witness
#             - 2 Rolant's Honor Guard
#             - 4 Silverwing Augmentor
# [ 55/117] Processing file ss055.png...
#             - 1 Rolant, the Iron Fist
#             - 1 Sword of the Sky King
#             - 4 Valkyrie Linebreaker
#             - 2 Silverwing Rallier
#             - 1 Primal Sigil
#             - 3 Clan Standard
#             - 4 Cobalt Monument
#             - 3 Cobalt Waystone
#             - 3 Steely Resolve
#             - 4 Blind Storyteller
#             - 4 Cliffside Porter
#             - 4 Cloudsnake Hatchling
# [ 56/117] Processing file ss056.png...
#             - 4 Crystal Dirk
#             - 3 Eilyn's Intervention
#             - 3 Farplace Finder
#             - 2 Frostwave
#             - 4 Gift of Battle
#             - 4 Hearty Stranger
#             - 4 Jump Kick
#             - 4 Levitate
#             - 3 Mischief Yeti
#             - 4 Permafrost
#             - 1 Powderglider
#             - 4 Savage Denial
# [ 57/117] Processing file ss057.png...
#             - 1 Savage Denial
#             - 2 Savage Skybrood
#             - 4 Shiver
#             - 1 Shiver
#             - 4 Sinister Opportunist
#             - 4 Snowcrust Yeti
#             - 3 Snowrager
#             - 3 Substitute
#             - 4 Unstable Form
#             - 4 Weather the Storm
#             - 1 Weather the Storm
#             - 4 Yeti Spy
# [ 58/117] Processing file ss058.png...
#             - 4 Backlash
#             - 4 Borderlands Waykeeper
#             - 4 Campfire Watchman
#             - 4 Changeestik
#             - 4 Cloudsnake Breeder
#             - 1 Cloudsnake Saddle
#             - 4 Darkbolt
#             - 2 Darkveil Agent
#             - 4 Dragonbreath
#             - 4 Dusk Raider
#             - 1 Dusk Raider
#             - 4 East-Wind Herald
# [ 59/117] Processing file ss059.png...
#             - 4 Eilyn's Favor
#             - 1 Eilyn's Favor
#             - 4 Entangling Vines
#             - 4 Fearless Yeti
#             - 3 Frost Talisman
#             - 4 Gruanform
#             - 4 Herald's Song
#             - 3 Horizon Seeker
#             - 4 Huddle Together
#             - 1 Huddle Together
#             - 1 Iceberg Mason
#             - 4 Kosul Huntsman
# [ 60/117] Processing file ss060.png...
#             - 4 Lightning Storm
#             - 4 Lightning Strike
#             - 4 Maelstrom Bell
#             - 3 Master Cartographer
#             - 2 Mating Call
#             - 2 Parry
#             - 2 Portent Reader
#             - 2 Read the Stars
#             - 4 Reinforced Towershield
#             - 4 Scaly Gruan
#             - 1 Scaly Gruan
#             - 4 Second Sight
# [ 61/117] Processing file ss061.png...
#             - 4 Snowfort Trumpeter
#             - 4 Static Bolt
#             - 1 Storm Talisman
#             - 3 Strategize
#             - 4 Talon Dive
#             - 1 Talon Dive
#             - 4 Tend the Flock
#             - 3 Torrential Downpour
#             - 4 Trailblaze
#             - 2 Twilight Hermit
#             - 4 Unseal
#             - 4 Violent Gust
# [ 62/117] Processing file ss062.png...
#             - 4 Wardwielder
#             - 1 Whispering Wind
#             - 4 Wild Cloudsnake
#             - 2 Wind Cloak
#             - 4 Winter's Grasp
#             - 4 Yeti Snowchucker
#             - 4 Yeti Snowslinger
#             - 4 Yeti Windflyer
#             - 4 Acquisitive Crow
#             - 4 Advance Scout
#             - 4 Cloudsnake Harrier
#             - 4 Cobalt Acolyte
# [ 63/117] Processing file ss063.png...
#             - 4 Cobalt Ring
#             - 2 Courier Albatross
#             - 4 Crafty Yeti
#             - 1 Crafty Yeti
#             - 1 Daring Pioneer
#             - 4 Electropy
#             - 1 Eye of Winter
#             - 4 Flash Freeze
#             - 4 Fledgling Avisaur
#             - 4 Foothills Alpha
#             - 4 Hailstorm
#             - 1 Horde Plunderer
# [ 64/117] Processing file ss064.png...
#             - 4 Ice Sprite
#             - 4 Icebow
#             - 2 Icebreaker
#             - 4 Jennev Merchant
#             - 4 Lethrai Darkstalker
#             - 1 Mind Link
#             - 4 Mirror Image
#             - 4 Polymorph
#             - 2 Rabid Yeti
#             - 1 Rabid Yeti
#             - 3 Shapeshifter's Mask
#             - 1 Skycrag Scalebreaker
# [ 65/117] Processing file ss065.png...
#             - 4 Skyrider Vanguard
#             - 1 Skyrider Vanguard
#             - 4 Skysnapper
#             - 4 Snowfort
#             - 4 South-Wind Herald
#             - 2 Storm Spiral
#             - 4 Stormcrasher
#             - 1 Stormcrasher
#             - 1 Sunken Tower
#             - 1 Temple Shihan
#             - 4 Thunderbird
#             - 4 Trumpeting Warhowler
# [ 66/117] Processing file ss066.png...
#             - 1 Tundra Explorer
#             - 3 Voracious Fosora
#             - 4 Wild Rider
#             - 4 Wisdom of the Elders
#             - 1 Wump, Party Starter
#             - 2 Yeti Furflinger
#             - 1 Clutchmate
#             - 3 Court Mage
#             - 1 Court Mage
#             - 4 Cutbrush Cartographer
#             - 1 Freewing Glider
#             - 4 Galeprowler
# [ 67/117] Processing file ss067.png...
#             - 2 Icespear Chucker
#             - 4 Jarrall's Frostkin
#             - 1 Jarrall's Frostkin
#             - 4 Jotun Cyclops
#             - 1 Lens of Clarity
#             - 4 Mass Entomancy
#             - 4 Nocturnal Kyrex
#             - 1 Rain of Frogs
#             - 1 Reclusive Scholar
#             - 1 Regression
#             - 2 Rejection
#             - 2 Resurface
# [ 68/117] Processing file ss068.png...
#             - 4 Ridgeline Watcher
#             - 4 Scavenging Spikeback
#             - 4 Serpent Mount
#             - 1 Serpent Mount
#             - 4 Serpent Trainer
#             - 4 Serpent Trainer
#             - 4 Skyward Seer
#             - 3 Slushdumper
#             - 3 Soaring Stranger
#             - 1 Spiritward Shaman
#             - 4 Stormcaller
#             - 4 Sudden Schism
# [ 69/117] Processing file ss069.png...
#             - 4 Torgov, Icecap Trader
#             - 4 Tyrannize
#             - 4 Windshaper
#             - 4 Yeti Troublemaker
#             - 4 Yetipult
#             - 4 Aerial Ace
#             - 1 Aeva, Eilyn's Elite
#             - 1 Big Brother
#             - 2 Cliffdiver Mantasaur
#             - 4 Cliffside Caretaker
#             - 4 Crystallize
#             - 4 First-Frost Shaman
# [ 70/117] Processing file ss070.png...
#             - 3 Gleaming Shield
#             - 4 Jotun Hurler
#             - 4 Jotun Punter
#             - 1 Jotun Punter
#             - 4 Jotun Warrior
#             - 1 Magus of the Mist
#             - 4 Primal Incarnation
#             - 4 Psionic Savant
#             - 4 Skycrag Wyvarch
#             - 4 Skywalk Instructor
#             - 1 Staff of Stories
#             - 3 Stampede Driver
# [ 71/117] Processing file ss071.png...
#             - 4 Swindle
#             - 1 Swindle
#             - 1 West-Wind Herald
#             - 2 Acantha's Outrider
#             - 4 Boltcrafter Shaman
#             - 1 Celestial Omen
#             - 4 Cirso's Meddling
#             - 4 Daraka, Queensguard
#             - 1 Eilyn's Frostrider
#             - 2 Hatchery Hunter
#             - 4 Iceknuckle Jotun
#             - 4 Justa, Regglar Jotun
# [ 72/117] Processing file ss072.png...
#             - 4 Lumbering Gruan
#             - 4 Maul
#             - 4 Moonlight Huntress
#             - 4 North-Wind Herald
#             - 2 Sapphire Dragon
#             - 2 Scouting Party
#             - 4 Shamanic Blast
#             - 4 Slope Sergeant
#             - 3 Speardiver
#             - 3 Thunderstrike Dragon
#             - 4 Adaptive Predator
#             - 4 Araktodon
# [ 73/117] Processing file ss073.png...
#             - 4 Bellowing Thunderfoot
#             - 4 Elysian Trailblazer
#             - 4 Enraged Araktodon
#             - 4 Hooru Teachings
#             - 4 Icequake
#             - 2 Mistveil Drake
#             - 2 Novice Herdrider
#             - 2 Rimescale Draconus
#             - 1 Eilyn, Queen of the Wilds
#             - 4 Surveying Mantasaur
#             - 3 Channel the Tempest
#             - 1 Shadow Sigil
# [ 74/117] Processing file ss074.png...
#             - 4 Amethyst Monument
#             - 4 Amethyst Waystone
#             - 2 Cabal Standard
#             - 4 Borrowed Violence
#             - 4 Affliction
#             - 1 Arachnophobia
#             - 4 Blood Beetle
#             - 4 Brash Shorthorn
#             - 1 Brash Shorthorn
#             - 3 Cabal Scavenger
#             - 4 Dark Return
#             - 4 Direfang Spider
# [ 75/117] Processing file ss075.png...
#             - 2 Direwood Slasher
#             - 4 Fallen Oni
#             - 1 Fallen Oni
#             - 3 Feral Spiteling
#             - 4 Ghostform
#             - 1 Ghostform
#             - 4 Grenamender
#             - 4 Harbinger's Bite
#             - 4 Horrifying Helm
#             - 4 Jack's Knife
#             - 2 Jack's Knife
#             - 4 Lock Horns
# [ 76/117] Processing file ss076.png...
#             - 3 Pilfer
#             - 1 Rat Cage
#             - 4 Sabotage
#             - 1 Secret Passage
#             - 2 Sewer Sludge
#             - 1 Sewer Sludge
#             - 4 Shakedown
#             - 4 Slumbering Stone
#             - 4 Spitefeeder
#             - 4 Suffocate
#             - 4 Swear Vengeance
#             - 4 Tock Tick
# [ 77/117] Processing file ss077.png...
#             - 4 Trusty Revolver
#             - 1 Vara's Intervention
#             - 2 Wisplight
#             - 2 Abduct
#             - 4 Afterimage
#             - 4 Annihilate
#             - 4 Argenport Instigator
#             - 4 Back-Alley Delinquent
#             - 2 Battlefield Scavenger
#             - 2 Blood Quill
#             - 1 Blood Quill
#             - 4 Cabal Cutthroat
# [ 78/117] Processing file ss078.png...
#             - 4 Cabal Slasher
#             - 4 Cowardice
#             - 2 Cull the Deck
#             - 4 Curator's Spear
#             - 4 Dark Wisp
#             - 4 Dark Wisp
#             - 4 Devour
#             - 2 Fenris Nightshade
#             - 4 Flashy Duelist
#             - 1 Flashy Duelist
#             - 4 Grenadin Bellower
#             - 1 Grenadin Bellower
# [ 79/117] Processing file ss079.png...
#             - 3 Heirloom Seeker
#             - 2 Infused Strike
#             - 4 Kerendon Steward
#             - 4 Lethrai Ranger
#             - 4 Lethrai Target Caller
#             - 4 Longshot Marksman
#             - 4 Lunging Wisp
#             - 1 Miris Nightshade
#             - 4 Mob Rule
#             - 1 Mournful Deathcap
#             - 2 Obliviobot
#             - 4 Piercing Grief
# [ 80/117] Processing file ss080.png...
#             - 4 Rapid Shot
#             - 4 Ripknife Assassin
#             - 4 Scare
#             - 4 Scavenging Vulture
#             - 4 Sleeping Draught
#             - 1 Sleeping Draught
#             - 4 Sporefolk
#             - 4 Territorial Elf
#             - 4 Threaten
#             - 1 Threaten
#             - 4 Unseen Agent
#             - 4 Vampire Bat
# [ 81/117] Processing file ss081.png...
#             - 4 Vara's Favor
#             - 1 Vara's Favor
#             - 4 Venomfang Dagger
#             - 4 Amethyst Acolyte
#             - 4 Amethyst Ring
#             - 4 Auric Interrogator
#             - 4 Banished Umbren
#             - 4 Beastcaller's Amulet
#             - 4 Blackguard Sidearm
#             - 1 Cabal Countess
#             - 3 Cat Burglar
#             - 2 Coronal Umbren
# [ 82/117] Processing file ss082.png...
#             - 1 Coronal Umbren
#             - 4 Daggerclaw Howler
#             - 4 Desperado
#             - 4 Devouring Shadow
#             - 4 Direwood Beastcaller
#             - 4 Duskcaller
#             - 4 Execute
#             - 4 Extract
#             - 4 Flickerling
#             - 4 Hair-Trigger Pistol
#             - 1 Hair-Trigger Pistol
#             - 4 Lethrai Memory-Keeper
# [ 83/117] Processing file ss083.png...
#             - 1 Lethrai Memory-Keeper
#             - 4 Lethrai Nightblade
#             - 4 Lifedrinker
#             - 4 Madness
#             - 4 Maimed Watchwing
#             - 1 Means to an End
#             - 2 Mug
#             - 4 Plague
#             - 3 Prickly Grenadin
#             - 4 Ravenous Thornbeast
#             - 4 Sadistic Valkyrie
#             - 2 Scavenge
# [ 84/117] Processing file ss084.png...
#             - 4 Scheme
#             - 2 Shadowlands Guide
#             - 4 Shadowstalker
#             - 4 Skeeter
#             - 4 Sorrow's Shroud
#             - 2 Sporebreath
#             - 4 Spur On
#             - 1 Spur On
#             - 3 Surgeon's Saw
#             - 2 Surgeon's Saw
#             - 1 Torrent of Spiders
#             - 4 Trigger-Happy
# [ 85/117] Processing file ss085.png...
#             - 3 Umbren Deathwatcher
#             - 3 Xenan Cultist
#             - 1 Xenan Cultist
#             - 4 Xenan Destroyer
#             - 1 Xenan Destroyer
#             - 4 Argenport Sewers
#             - 4 Back-Alley Bouncer
#             - 1 Back-Alley Bouncer
#             - 1 Betray the Cause
#             - 1 Burglarize
#             - 4 Cabal Bludgeoner
#             - 4 Cabal Recruiter
# [ 86/117] Processing file ss086.png...
#             - 4 Consuming Greed
#             - 1 Consuming Greed
#             - 4 Corrupted Umbren
#             - 4 Cripple
#             - 4 Deathstrike
#             - 1 Devious Drone
#             - 4 Dueling Pistols
#             - 4 Extinguish
#             - 1 Fangs in the Dark
#             - 1 Fangs in the Dark
#             - 4 Final-Shot Rioter
#             - 4 Hatecleaver
# [ 87/117] Processing file ss087.png...
#             - 4 Holdup
#             - 2 Impending Doom
#             - 4 In Cold Blood
#             - 2 Kyrex Coach Driver
#             - 4 Lethrai Falchion
#             - 2 Lethrai Intimidator
#             - 4 Memory Dredger
#             - 4 Minotaur Lighthoof
#             - 1 Minotaur Lighthoof
#             - 4 Relentless Gorehorn
#             - 4 Savage Stranger
#             - 4 Soul Collector
# [ 88/117] Processing file ss088.png...
#             - 1 Soulbringer
#             - 4 Stonescar Magus
#             - 1 Stonescar Magus
#             - 2 Street Leecher
#             - 4 Subvert
#             - 1 Transmogrifier
#             - 1 Umbral Edge
#             - 4 Vainglory Patrol
#             - 4 Vile Varmint
#             - 4 Xenan Fanatic
#             - 2 Ashara, the Deadshot
#             - 2 Breathstealer
# [ 89/117] Processing file ss089.png...
#             - 4 Colony Matron
#             - 4 Cover of Darkness
#             - 3 Eye for an Eye
#             - 2 Grasping at Shadows
#             - 4 Grimy Alp-luachra
#             - 1 Headsman's Axe
#             - 4 Lethrai Bladewhirl
#             - 1 Lurking Sanguar
#             - 4 Merciless Stranger
#             - 3 Moonlit Gargoyle
#             - 2 Oblivion Spike
#             - 2 Obrak, the Feaster
# [ 90/117] Processing file ss090.png...
#             - 2 Pillar of Dreams
#             - 1 Stonescar Scrapper
#             - 4 Stray into Shadow
#             - 1 The End is Near
#             - 4 Triggerman
#             - 1 Triggerman
#             - 3 Umbren Coaxer
#             - 1 Umbren Reaper
#             - 4 Umbren Thirster
#             - 2 Argenport Ringmaster
#             - 4 Cut Ties
#             - 4 Direwood Prowler
# [ 91/117] Processing file ss091.png...
#             - 1 Direwood Prowler
#             - 4 Direwood Rampager
#             - 4 Drifting Death
#             - 3 Finback Komonat
#             - 3 Gunrustler
#             - 4 Horsesnatcher Bat
#             - 1 Sadistic Glee
#             - 4 Slimespitter Slug
#             - 4 Spirit Drain
#             - 1 Azindel's Gift
#             - 4 Cabal Rogue
#             - 1 Cabal Rogue
# [ 92/117] Processing file ss092.png...
#             - 1 Dangerous Bargain
#             - 4 Inspire Obedience
#             - 3 Repulsive Gorger
#             - 4 Shadowlands Feaster
#             - 1 Improvised Club
#             - 4 Sleepless Night
#             - 1 Umbren Occluder
#             - 1 Vara, Fate-Touched
#             - 4 Praxis Banner
#             - 1 Praxis Banner
#             - 4 Seat of Impulse
#             - 4 Alluring Ember
# [ 93/117] Processing file ss093.png...
#             - 4 Noble Firemane
#             - 4 Purify
#             - 1 Purify
#             - 4 Waker of Ancients
#             - 4 Champion of Impulse
#             - 4 Journeyman Armorer
#             - 4 Magus of Celerity
#             - 2 Mysterium Orb
#             - 4 Brilliant Discovery
#             - 2 Brilliant Discovery
#             - 4 Clever Stranger
#             - 4 Diogo Málaga
# [ 94/117] Processing file ss094.png...
#             - 4 Monolith Guardian
#             - 4 Sandglass Juggernaut
#             - 2 Shatterglass Mage
#             - 1 Stoneshell Walker
#             - 4 Talir's Choice
#             - 1 Talir's Choice
#             - 4 Workshop Forge
#             - 1 Heart of the Vault
#             - 1 Moment of Creation
#             - 4 Sandglass Sentinel
#             - 1 Crest of Glory
#             - 4 Rakano Banner
# [ 95/117] Processing file ss095.png...
#             - 4 Seat of Glory
#             - 3 Bear Arms
#             - 4 Champion of Glory
#             - 4 Ijin's Choice
#             - 2 Rakano Artisan
#             - 1 Rakano Artisan
#             - 4 Crownwatch Deserter
#             - 4 Sower of Dissent
#             - 4 Sword of Icaria
#             - 1 Whirling Duo
#             - 1 Whirling Duo
#             - 4 Battleblur Centaur
# [ 96/117] Processing file ss096.png...
#             - 1 Eaton, Seditious Noble
#             - 4 Longhorn Sergeant
#             - 1 Longhorn Sergeant
#             - 4 Renegade Valkyrie
#             - 1 Renegade Valkyrie
#             - 3 Righteous Fury
#             - 1 Rise to the Challenge
#             - 4 Field Captain
#             - 1 Field Captain
#             - 2 Deadeye
#             - 4 Jekk, the Bounty Hunter
#             - 1 Starsteel Daisho
# [ 97/117] Processing file ss097.png...
#             - 4 Seat of Fury
#             - 4 Skycrag Banner
#             - 1 Skycrag Banner
#             - 4 Champion of Fury
#             - 4 Kaleb's Choice
#             - 1 Kaleb's Choice
#             - 4 Rockslide
#             - 2 Calderan Cradle
#             - 4 Clan Hero
#             - 2 Crunch, the Hoarder
#             - 1 Howling Peak Smuggler
#             - 1 Iceberg Shineefinder
# [ 98/117] Processing file ss098.png...
#             - 1 Mighty Strikes
#             - 4 Pokpok, Rockpacker
#             - 1 Vadius, Clan Father
#             - 4 Hunter's Harpoon
#             - 4 Mortar
#             - 4 Storm Glider
#             - 4 Unexpected Results
#             - 2 Bloodthirsty Brawler
#             - 2 Iceberg Warchief
#             - 4 Towering Stranger
#             - 1 Crill, Merciless Pillager
#             - 1 Knucklebones
# [ 99/117] Processing file ss099.png...
#             - 4 Topaz Drake
#             - 1 Molot & Nakova
#             - 4 Decimate
#             - 4 Seat of Chaos
#             - 4 Stonescar Banner
#             - 1 Stonescar Banner
#             - 4 Combust
#             - 2 Hair-Trigger Stranger
#             - 4 Obsidian Golem
#             - 4 Quarry
#             - 3 Treachery
#             - 2 Champion of Chaos
# [100/117] Processing file ss100.png...
#             - 4 Overwinder
#             - 3 Recycler
#             - 1 Bandit Queen
#             - 2 Black Iron Manacles
#             - 1 Clan Huntcaller
#             - 1 Stonescar Pickaxe
#             - 3 Jekk's Choice
#             - 1 Runic Revolver
#             - 4 Warband Chieftain
#             - 1 Failed Reflection
#             - 1 Infernal Tyrant
#             - 4 Smuggler's Stash
# [101/117] Processing file ss101.png...
#             - 4 Combrei Banner
#             - 4 Seat of Progress
#             - 3 Alessi, Combrei Archmage
#             - 4 Awakened Student
#             - 4 Desert Marshal
#             - 4 Jaril, Amaran Ghostblade
#             - 4 Safe Return
#             - 1 Safe Return
#             - 4 Combrei Emissary
#             - 4 Combrei Healer
#             - 1 Combrei Healer
#             - 1 Shush
# [102/117] Processing file ss102.png...
#             - 1 Stand Together
#             - 4 Vodakhan's Staff
#             - 4 Copperhall Elite
#             - 1 Enlightened Stranger
#             - 4 Karmic Guardian
#             - 1 Penitent Bull
#             - 1 Stronghold's Visage
#             - 1 Champion of Progress
#             - 4 Minotaur Ambassador
#             - 2 Siraf's Choice
#             - 4 Elysian Banner
#             - 4 Seat of Wisdom
# [103/117] Processing file ss103.png...
#             - 1 Derry Cathain, Ripclaw Rider
#             - 4 Equivocate
#             - 1 Honeypot
#             - 4 Storm Lynx
#             - 4 Twinning Ritual
#             - 4 Amaran Camel
#             - 4 False Prince
#             - 1 Great Valley Smuggler
#             - 4 Pteriax Hatchling
#             - 4 Avisaur Patriarch
#             - 1 Champion of Wisdom
#             - 1 Cirso's Choice
# [104/117] Processing file ss104.png...
#             - 3 Crystalline Chalice
#             - 4 Nesting Avisaur
#             - 3 Scaletender
#             - 1 Bazaar Stampede
#             - 1 Cirso, the Great Glutton
#             - 1 Explorer Emeritus
#             - 3 Hunting Pteriax
#             - 1 Fortunate Stranger
#             - 1 Tunneling Gargantua
#             - 2 Crest of Mystery
#             - 4 Seat of Mystery
#             - 4 Xenan Banner
# [105/117] Processing file ss105.png...
#             - 4 Bloodcall Invocation
#             - 4 Blistersting Wasp
#             - 3 Lethrai Courtier
#             - 4 Mitotic Wisp
#             - 4 Vara's Choice
#             - 1 Vara's Choice
#             - 1 Ayan, the Abductor
#             - 1 Banish
#             - 1 Ebon Dune Smuggler
#             - 1 Sadistic Ritualist
#             - 4 Shadowlands Bonepicker
#             - 4 Cruciation
# [106/117] Processing file ss106.png...
#             - 2 Dread
#             - 2 Duskwalker
#             - 4 Katra, the Devoted
#             - 1 Mask of Torment
#             - 1 Preserver of Dualities
#             - 4 Xenan Augury
#             - 2 Xenan Augury
#             - 4 Xenan Cupbearer
#             - 4 Bloodcall Invoker
#             - 4 Champion of Mystery
#             - 1 Siphon Vitality
#             - 4 Prophetic Stranger
# [107/117] Processing file ss107.png...
#             - 4 Hooru Banner
#             - 4 Seat of Order
#             - 4 Bring Down
#             - 2 Kothon, the Far-Watcher
#             - 2 Linebreaker's Shield
#             - 4 Vision of Austerity
#             - 4 Aerialist Trainer
#             - 4 Eilyn's Choice
#             - 1 Eilyn's Choice
#             - 4 Hooru Pacifier
#             - 4 Spellshield Architect
#             - 2 Long Live the Queen
# [108/117] Processing file ss108.png...
#             - 4 Master's Lesson
#             - 4 Shelterwing Rider
#             - 4 Shield Bash
#             - 3 Champion of Order
#             - 2 Deepwood Ranger
#             - 4 Duelist's Blade
#             - 1 Duelist's Blade
#             - 2 Gate Guardian
#             - 4 Highwind Glider
#             - 4 Kosul Brigade
#             - 3 Meditative Stranger
#             - 2 Nostrix, Lord of Visions
# [109/117] Processing file ss109.png...
#             - 4 Argenport Banner
#             - 4 Seat of Vengeance
#             - 4 Anointer of the Faithful
#             - 4 Auric Bully
#             - 4 Auric Vigilante
#             - 3 Lost Scroll
#             - 1 Back for More
#             - 4 Bloodletter
#             - 1 Hidden Road Smuggler
#             - 1 Resilient Wagoneer
#             - 4 Rooftop Vigilante
#             - 4 Slay
# [110/117] Processing file ss110.png...
#             - 1 Slay
#             - 4 Stonepowder Alchemist
#             - 3 Champion of Vengeance
#             - 4 Sanguine Sword
#             - 1 Sanguine Sword
#             - 4 Streetwise Informant
#             - 1 Bereaved Stranger
#             - 2 Inquisitor Makto
#             - 3 Knight of Sorrow
#             - 4 Rolant's Choice
#             - 1 Rolant's Choice
#             - 4 Tavrod, Auric Broker
# [111/117] Processing file ss111.png...
#             - 4 Valkyrie Denouncer
#             - 1 Valkyrie Denouncer
#             - 1 Grinva, Judge of Battles
#             - 1 Crest of Cunning
#             - 4 Feln Banner
#             - 4 Seat of Cunning
#             - 4 Twilight Raptor
#             - 4 Gorgon Swiftblade
#             - 1 Gorgon Swiftblade
#             - 4 Haunting Scream
#             - 4 Rindra's Choice
#             - 1 Feln Bloodcaster
# [112/117] Processing file ss112.png...
#             - 4 Gorgon Fanatic
#             - 2 Recurring Nightmare
#             - 4 Skywalk Enforcer
#             - 4 Trickster's Cloak
#             - 1 Miner's Canary
#             - 1 Ancient of the Ice Caves
#             - 4 Cabal Spymaster
#             - 4 Feeding Time
#             - 1 Feeding Time
#             - 4 Lethrai Skystrider
#             - 4 Champion of Cunning
#             - 2 Spell Swipe
# [113/117] Processing file ss113.png...
#             - 1 Spell Swipe
#             - 2 Snowcrush Animist
#             - 4 Token of Instinct
#             - 1 Jennev Cargo
#             - 2 Carnivorous Sauropod
#             - 3 Display of Instinct
#             - 2 Token of Honor
#             - 1 Ixtun Cargo
#             - 1 Display of Honor
#             - 4 Kosul Beastmaster
#             - 4 Token of Ambition
#             - 4 Blaze
# [114/117] Processing file ss114.png...
#             - 4 Token of Vision
#             - 3 Bleak Basin Guide
#             - 1 Display of Vision
#             - 2 Token of Knowledge
#             - 1 Display of Knowledge
#             - 3 Tumbling Sloth
#             - 4 Triumphant Stranger
#             - 4 Nictotraxian
#             - 4 Diplomatic Seal
#             - 4 Spiked Helm
#             - 4 Stranger's Mark
#             - 4 Alchemist's Concoction
# [115/117] Processing file ss115.png...
#             - 4 Astromancer's Compass
#             - 2 Family Charter
#             - 4 Horus Traver
#             - 2 Veteran Strategist
#             - 4 Worn Shield
#             - 4 Argenport Stranger
#             - 3 Bannerman
#             - 4 Combrei Stranger
#             - 4 Daze
#             - 4 Elysian Stranger
#             - 4 Feln Stranger
#             - 4 Hooru Stranger
# [116/117] Processing file ss116.png...
#             - 1 Hooru Stranger
#             - 2 Petition
#             - 4 Praxis Stranger
#             - 4 Rakano Stranger
#             - 2 Recon Tower
#             - 4 Reunite
#             - 4 Skycrag Stranger
#             - 4 Stonescar Stranger
#             - 4 Xenan Stranger
#             - 4 Alchemical Blast
#             - 1 Alchemical Blast
#             - 1 Disrupt
# [117/117] Processing file ss117.png...
#             - 4 Forsworn Stranger
#             - 2 Iron Hook
#             - 2 Makeshift Barrier
#             - 2 Replicator Engine
#             - 1 Replicator Engine
#             - 2 Momentum Builder
#             - 4 Rotorcycle
#             - 4 Caiphus, Wandering King
#             - 4 Rumbling Contraption
# [ERROR] Problem identifying card 10 in screenshot ss117.png!
# [ERROR] Problem identifying card 11 in screenshot ss117.png!
# [ERROR] Problem identifying card 12 in screenshot ss117.png!
# Wall time: 20min 44s

# %%
my_collection=[]
for card in library:
    if library[card]['owned']>0:
        my_collection.append('{} {} (Set{} #{})'.format(library[card]['owned'],
                                                        card,
                                                        library[card]['set'],
                                                        library[card]['id']))
with open(collection_file,'w') as f:
    f.writelines([card+'\n' for card in my_collection])

# %% [markdown]
# Errors are to be expected at the last few cards, where there is actually no card on the screenshot.

# %%
errors
# Out:
# ['[ERROR] Problem identifying card 10 in screenshot ss117.png!',
#  '[ERROR] Problem identifying card 11 in screenshot ss117.png!',
#  '[ERROR] Problem identifying card 12 in screenshot ss117.png!']
